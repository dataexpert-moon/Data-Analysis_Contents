# %% [markdown]
# # Pandas 한번에 제대로 배우기

# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd
pd.__version__
# Out:
# '1.1.3'

# %% [markdown]
# ## Pandas 객체

# %% [markdown]
# ### Series 객체

# %%
s = pd.Series([0, 0.25, 0.5, 0.75, 1.0]) #인덱스와 함께 데이터가 저장
print(s)
# Out:
# 0    0.00
# 1    0.25
# 2    0.50
# 3    0.75
# 4    1.00
# dtype: float64

# %%
s.values #값만 추출
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s[1]
# Out:
# 0.25

# %%
s[1:4]
# Out:
# 1    0.25
# 2    0.50
# 3    0.75
# dtype: float64

# %%
s = pd.Series([0, 0.25, 0.5, 0.75, 1.0], 
              index=['a','b','c','d','e'])
print(s)
# Out:
# a    0.00
# b    0.25
# c    0.50
# d    0.75
# e    1.00
# dtype: float64

# %%
s['c']
# Out:
# 0.5

# %%
s[['c','d','e']]
# Out:
# c    0.50
# d    0.75
# e    1.00
# dtype: float64

# %%
'b' in s
# Out:
# True

# %%
s = pd.Series([0, 0.25, 0.5, 0.75, 1.0],
              index=[2,4,6,8,10])
print(s)
# Out:
# 2     0.00
# 4     0.25
# 6     0.50
# 8     0.75
# 10    1.00
# dtype: float64

# %%
s[4]
# Out:
# 0.25

# %%
s[2:]
# Out:
# 6     0.50
# 8     0.75
# 10    1.00
# dtype: float64

# %%
s.unique()
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
s.value_counts()
# Out:
# 1.00    1
# 0.75    1
# 0.50    1
# 0.25    1
# 0.00    1
# dtype: int64

# %%
s.isin([0.25,0.75]) #불리언 형태로 반환
# Out:
# 2     False
# 4      True
# 6     False
# 8      True
# 10    False
# dtype: bool

# %%
pop_tuple = {'서울특별시': 9720846,
            '부산광역시': 3404423,
            '인천광역시': 2947217,
            '대구광역시': 2427954,
            '대전광역시': 1471040,
            '광주광역시': 1455048}
print(pop_tuple)
population = pd.Series(pop_tuple)
population
# Out:
# {'서울특별시': 9720846, '부산광역시': 3404423, '인천광역시': 2947217, '대구광역시': 2427954, '대전광역시': 1471040, '광주광역시': 1455048}
# 서울특별시    9720846
# 부산광역시    3404423
# 인천광역시    2947217
# 대구광역시    2427954
# 대전광역시    1471040
# 광주광역시    1455048
# dtype: int64

# %%
population['서울특별시']
# Out:
# 9720846

# %%
population['서울특별시':'인천광역시'] #슬라이싱
# Out:
# 서울특별시    9720846
# 부산광역시    3404423
# 인천광역시    2947217
# dtype: int64

# %% [markdown]
# ### DataFrame 객체

# %%
pd.DataFrame([{'A':2, 'B':4, 'D':3}, {'A':4, 'B':5, 'C':7}])
# Out:
#    A  B    D    C
# 0  2  4  3.0  NaN
# 1  4  5  NaN  7.0

# %%
pd.DataFrame(np.random.rand(5,5),
            columns=['A','B','C','D','E'],
            index=[1,2,3,4,5])
# Out:
#           A         B         C         D         E
# 1  0.167854  0.811793  0.416099  0.778004  0.965394
# 2  0.383794  0.482555  0.235638  0.387453  0.306216
# 3  0.855596  0.851484  0.642611  0.663308  0.546583
# 4  0.261225  0.175298  0.069226  0.770065  0.613861
# 5  0.005356  0.880659  0.498233  0.667850  0.630685

# %%
male_tuple = {'서울특별시': 4732275,
              '부산광역시': 1668618,
              '인천광역시': 1476813,
              '대구광역시': 1198815,
              '대전광역시': 734441,
              '광주광역시': 720060}
male = pd.Series(male_tuple)
male
# Out:
# 서울특별시    4732275
# 부산광역시    1668618
# 인천광역시    1476813
# 대구광역시    1198815
# 대전광역시     734441
# 광주광역시     720060
# dtype: int64

# %%
female_tuple = {'서울특별시': 4988571,
              '부산광역시': 1735805,
              '인천광역시': 1470404,
              '대구광역시': 1229139,
              '대전광역시': 736599,
              '광주광역시': 734988}
female = pd.Series(female_tuple)
female
# Out:
# 서울특별시    4988571
# 부산광역시    1735805
# 인천광역시    1470404
# 대구광역시    1229139
# 대전광역시     736599
# 광주광역시     734988
# dtype: int64

# %%
korea_df = pd.DataFrame({'인구수': population,
                         '남자인구수': male,
                         '여자인구수': female})
korea_df
# Out:
#            인구수    남자인구수    여자인구수
# 서울특별시  9720846  4732275  4988571
# 부산광역시  3404423  1668618  1735805
# 인천광역시  2947217  1476813  1470404
# 대구광역시  2427954  1198815  1229139
# 대전광역시  1471040   734441   736599
# 광주광역시  1455048   720060   734988

# %%
#속성
korea_df.index
# Out:
# Index(['서울특별시', '부산광역시', '인천광역시', '대구광역시', '대전광역시', '광주광역시'], dtype='object')

# %%
korea_df.columns
# Out:
# Index(['인구수', '남자인구수', '여자인구수'], dtype='object')

# %%
korea_df['여자인구수']
# Out:
# 서울특별시    4988571
# 부산광역시    1735805
# 인천광역시    1470404
# 대구광역시    1229139
# 대전광역시     736599
# 광주광역시     734988
# Name: 여자인구수, dtype: int64

# %%
korea_df['서울특별시':'인천광역시']
# Out:
#            인구수    남자인구수    여자인구수
# 서울특별시  9720846  4732275  4988571
# 부산광역시  3404423  1668618  1735805
# 인천광역시  2947217  1476813  1470404

# %% [markdown]
# ### Index 객체

# %%
idx = pd.Index([2,4,6,8,10])
idx
# Out:
# Int64Index([2, 4, 6, 8, 10], dtype='int64')

# %%
idx[1]
# Out:
# 4

# %%
idx[1:2:2]
# Out:
# Int64Index([4], dtype='int64')

# %%
idx[-1::]
# Out:
# Int64Index([10], dtype='int64')

# %%
idx[::2]
# Out:
# Int64Index([2, 6, 10], dtype='int64')

# %%
print(idx)
print(idx.size)
print(idx.shape)
print(idx.ndim)
print(idx.dtype)
# Out:
# Int64Index([2, 4, 6, 8, 10], dtype='int64')
# 5
# (5,)
# 1
# int64

# %% [markdown]
# #### Index 연산

# %%
idx1 = pd.Index([1,2,4,6,8])
idx2 = pd.Index([2,4,5,6,7])
print(idx1.append(idx2))
print(idx1.difference(idx2)) # 차집합
print(idx1 - idx2)
print(idx1.intersection(idx2)) # 교집합
print(idx1 & idx2)
print(idx1.union(idx2))
print(idx1 | idx2)
print(idx1.delete(0))
print(idx1.drop(1))
print(idx1 ^ idx2) #여집합
# Out:
# Int64Index([1, 2, 4, 6, 8, 2, 4, 5, 6, 7], dtype='int64')
# Int64Index([1, 8], dtype='int64')
# Int64Index([-1, -2, -1, 0, 1], dtype='int64')
# Int64Index([2, 4, 6], dtype='int64')
# Int64Index([2, 4, 6], dtype='int64')
# Int64Index([1, 2, 4, 5, 6, 7, 8], dtype='int64')
# Int64Index([1, 2, 4, 5, 6, 7, 8], dtype='int64')
# Int64Index([2, 4, 6, 8], dtype='int64')
# Int64Index([2, 4, 6, 8], dtype='int64')
# Int64Index([1, 5, 7, 8], dtype='int64')

# %% [markdown]
# ---

# %% [markdown]
# ## 인덱싱(Indexing)

# %%
s = pd.Series([0, 0.25, 0.5, 0.75, 1.0],
              index=['a','b','c','d','e'])
s
# Out:
# a    0.00
# b    0.25
# c    0.50
# d    0.75
# e    1.00
# dtype: float64

# %%
s['b']
# Out:
# 0.25

# %%
'b' in s
# Out:
# True

# %%
s.keys()
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
list(s.items())
# Out:
# [('a', 0.0), ('b', 0.25), ('c', 0.5), ('d', 0.75), ('e', 1.0)]

# %%
s['f'] = 1.25 #새로운값 추가
s
# Out:
# a    0.00
# b    0.25
# c    0.50
# d    0.75
# e    1.00
# f    1.25
# dtype: float64

# %%
s['a':'d'] # s[0:4]와 같음
# Out:
# a    0.00
# b    0.25
# c    0.50
# d    0.75
# dtype: float64

# %%
s[0:4]
# Out:
# a    0.00
# b    0.25
# c    0.50
# d    0.75
# dtype: float64

# %%
s[(s > 0.4) & (s < 0.8)]
# Out:
# c    0.50
# d    0.75
# dtype: float64

# %%
s[['a','c','e']] #원하는 부분만 추출하기
# Out:
# a    0.0
# c    0.5
# e    1.0
# dtype: float64

# %% [markdown]
# ### Series 인덱싱

# %%
s = pd.Series(['a','b','c','d','e'],
              index=[1,3,5,7,9])
s
# Out:
# 1    a
# 3    b
# 5    c
# 7    d
# 9    e
# dtype: object

# %%
s[1]
# Out:
# 'a'

# %%
s[2:4]
# Out:
# 5    c
# 7    d
# dtype: object

# %%
s.iloc[1] #숫자1인 인덱스값을 추출하는 것이 아닌 인덱스위치에 있는 값 출력
# Out:
# 'b'

# %%
s.iloc[2:4]
# Out:
# 5    c
# 7    d
# dtype: object

# %%
s.reindex(range(10))
# Out:
# 0    NaN
# 1      a
# 2    NaN
# 3      b
# 4    NaN
# 5      c
# 6    NaN
# 7      d
# 8    NaN
# 9      e
# dtype: object

# %%
s.reindex(range(10), method='bfill') #NaN값에 이전값을 채워주기
# Out:
# 0    a
# 1    a
# 2    b
# 3    b
# 4    c
# 5    c
# 6    d
# 7    d
# 8    e
# 9    e
# dtype: object

# %% [markdown]
# ### DataFrame 인덱싱

# %%
korea_df
# Out:
#            인구수    남자인구수    여자인구수
# 서울특별시  9720846  4732275  4988571
# 부산광역시  3404423  1668618  1735805
# 인천광역시  2947217  1476813  1470404
# 대구광역시  2427954  1198815  1229139
# 대전광역시  1471040   734441   736599
# 광주광역시  1455048   720060   734988

# %%
korea_df['남자인구수']
# Out:
# 서울특별시    4732275
# 부산광역시    1668618
# 인천광역시    1476813
# 대구광역시    1198815
# 대전광역시     734441
# 광주광역시     720060
# Name: 남자인구수, dtype: int64

# %%
korea_df.남자인구수 #위와 똑같은 결과 출력
# Out:
# 서울특별시    4732275
# 부산광역시    1668618
# 인천광역시    1476813
# 대구광역시    1198815
# 대전광역시     734441
# 광주광역시     720060
# Name: 남자인구수, dtype: int64

# %%
korea_df.여자인구수
# Out:
# 서울특별시    4988571
# 부산광역시    1735805
# 인천광역시    1470404
# 대구광역시    1229139
# 대전광역시     736599
# 광주광역시     734988
# Name: 여자인구수, dtype: int64

# %%
korea_df['남여비율'] = (korea_df['남자인구수'] * 100 / korea_df['여자인구수'])
korea_df
# Out:
#            인구수    남자인구수    여자인구수        남여비율
# 서울특별시  9720846  4732275  4988571   94.862336
# 부산광역시  3404423  1668618  1735805   96.129346
# 인천광역시  2947217  1476813  1470404  100.435867
# 대구광역시  2427954  1198815  1229139   97.532907
# 대전광역시  1471040   734441   736599   99.707032
# 광주광역시  1455048   720060   734988   97.968946

# %%
korea_df.values
# Out:
# array([[9.72084600e+06, 4.73227500e+06, 4.98857100e+06, 9.48623363e+01],
#        [3.40442300e+06, 1.66861800e+06, 1.73580500e+06, 9.61293463e+01],
#        [2.94721700e+06, 1.47681300e+06, 1.47040400e+06, 1.00435867e+02],
#        [2.42795400e+06, 1.19881500e+06, 1.22913900e+06, 9.75329072e+01],
#        [1.47104000e+06, 7.34441000e+05, 7.36599000e+05, 9.97070319e+01],
#        [1.45504800e+06, 7.20060000e+05, 7.34988000e+05, 9.79689464e+01]])

# %%
korea_df.T #전치행렬
# Out:
#               서울특별시         부산광역시         인천광역시         대구광역시         대전광역시  \
# 인구수    9.720846e+06  3.404423e+06  2.947217e+06  2.427954e+06  1.471040e+06
# 남자인구수  4.732275e+06  1.668618e+06  1.476813e+06  1.198815e+06  7.344410e+05
# 여자인구수  4.988571e+06  1.735805e+06  1.470404e+06  1.229139e+06  7.365990e+05
# 남여비율   9.486234e+01  9.612935e+01  1.004359e+02  9.753291e+01  9.970703e+01
#
#               광주광역시
# 인구수    1.455048e+06
# 남자인구수  7.200600e+05
# 여자인구수  7.349880e+05
# 남여비율   9.796895e+01

# %%
korea_df.values[0] #서울특별시만 출력
# Out:
# array([9.72084600e+06, 4.73227500e+06, 4.98857100e+06, 9.48623363e+01])

# %%
korea_df['인구수']
# Out:
# 서울특별시    9720846
# 부산광역시    3404423
# 인천광역시    2947217
# 대구광역시    2427954
# 대전광역시    1471040
# 광주광역시    1455048
# Name: 인구수, dtype: int64

# %%
korea_df.loc[:'인천광역시',:'남자인구수']
# Out:
#            인구수    남자인구수
# 서울특별시  9720846  4732275
# 부산광역시  3404423  1668618
# 인천광역시  2947217  1476813

# %%
korea_df.loc[(korea_df['여자인구수']>=1000000)]
# Out:
#            인구수    남자인구수    여자인구수        남여비율
# 서울특별시  9720846  4732275  4988571   94.862336
# 부산광역시  3404423  1668618  1735805   96.129346
# 인천광역시  2947217  1476813  1470404  100.435867
# 대구광역시  2427954  1198815  1229139   97.532907

# %%
korea_df.loc[(korea_df.인구수 < 2000000)]
# Out:
#            인구수   남자인구수   여자인구수       남여비율
# 대전광역시  1471040  734441  736599  99.707032
# 광주광역시  1455048  720060  734988  97.968946

# %%
korea_df.loc[(korea_df.인구수 > 2500000)]
# Out:
#            인구수    남자인구수    여자인구수        남여비율
# 서울특별시  9720846  4732275  4988571   94.862336
# 부산광역시  3404423  1668618  1735805   96.129346
# 인천광역시  2947217  1476813  1470404  100.435867

# %%
korea_df.loc[(korea_df.남여비율 >= 100)]
# Out:
#            인구수    남자인구수    여자인구수        남여비율
# 인천광역시  2947217  1476813  1470404  100.435867

# %%
korea_df.loc[(korea_df.인구수 >= 2500000) & (korea_df.남여비율 > 100)]
# Out:
#            인구수    남자인구수    여자인구수        남여비율
# 인천광역시  2947217  1476813  1470404  100.435867

# %%
korea_df.iloc[:3, :2]
# Out:
#            인구수    남자인구수
# 서울특별시  9720846  4732275
# 부산광역시  3404423  1668618
# 인천광역시  2947217  1476813

# %% [markdown]
# ### 다중 인덱싱(Multi Indexing)
#
# * 1차원의 Series와 2차원의 DataFrame 객체를 넘어 3차원, 4차원 이상의 고차원 데이터 처리
# * 단일 인덱스 내에 여러 인덱스를 포함하는 다중 인덱싱

# %% [markdown]
# #### 다중 인덱스 Series

# %%
korea_df
# Out:
#            인구수    남자인구수    여자인구수        남여비율
# 서울특별시  9720846  4732275  4988571   94.862336
# 부산광역시  3404423  1668618  1735805   96.129346
# 인천광역시  2947217  1476813  1470404  100.435867
# 대구광역시  2427954  1198815  1229139   97.532907
# 대전광역시  1471040   734441   736599   99.707032
# 광주광역시  1455048   720060   734988   97.968946

# %%
idx_tuples = [('서울특별시', 2010), ('서울특별시', 2020),
              ('부산광역시', 2010), ('부산광역시', 2020), 
              ('인천광역시', 2010), ('인천광역시', 2020),
              ('대구광역시', 2010), ('대구광역시', 2020),
              ('대전광역시', 2010), ('대전광역시', 2020),
              ('광주광역시', 2010), ('광주광역시', 2020)]
idx_tuples
# Out:
# [('서울특별시', 2010),
#  ('서울특별시', 2020),
#  ('부산광역시', 2010),
#  ('부산광역시', 2020),
#  ('인천광역시', 2010),
#  ('인천광역시', 2020),
#  ('대구광역시', 2010),
#  ('대구광역시', 2020),
#  ('대전광역시', 2010),
#  ('대전광역시', 2020),
#  ('광주광역시', 2010),
#  ('광주광역시', 2020)]

# %%
pop_tuples = [10312345, 9720846,
              2567910, 3404423,
              2758296, 2947217,
              2511676, 2427954,
              1503664, 1471040,
              1454636, 1455048]

population = pd.Series(pop_tuples, index=idx_tuples)
population
# Out:
# (서울특별시, 2010)    10312345
# (서울특별시, 2020)     9720846
# (부산광역시, 2010)     2567910
# (부산광역시, 2020)     3404423
# (인천광역시, 2010)     2758296
# (인천광역시, 2020)     2947217
# (대구광역시, 2010)     2511676
# (대구광역시, 2020)     2427954
# (대전광역시, 2010)     1503664
# (대전광역시, 2020)     1471040
# (광주광역시, 2010)     1454636
# (광주광역시, 2020)     1455048
# dtype: int64

# %%
midx = pd.MultiIndex.from_tuples(idx_tuples)
midx
# Out:
# MultiIndex([('서울특별시', 2010),
#             ('서울특별시', 2020),
#             ('부산광역시', 2010),
#             ('부산광역시', 2020),
#             ('인천광역시', 2010),
#             ('인천광역시', 2020),
#             ('대구광역시', 2010),
#             ('대구광역시', 2020),
#             ('대전광역시', 2010),
#             ('대전광역시', 2020),
#             ('광주광역시', 2010),
#             ('광주광역시', 2020)],
#            )

# %%
population = population.reindex(midx)
population
# Out:
# 서울특별시  2010    10312345
#        2020     9720846
# 부산광역시  2010     2567910
#        2020     3404423
# 인천광역시  2010     2758296
#        2020     2947217
# 대구광역시  2010     2511676
#        2020     2427954
# 대전광역시  2010     1503664
#        2020     1471040
# 광주광역시  2010     1454636
#        2020     1455048
# dtype: int64

# %%
population[:, 2010]
# Out:
# 서울특별시    10312345
# 부산광역시     2567910
# 인천광역시     2758296
# 대구광역시     2511676
# 대전광역시     1503664
# 광주광역시     1454636
# dtype: int64

# %%
population['대전광역시',:]
# Out:
# 2010    1503664
# 2020    1471040
# dtype: int64

# %%
korea_mdf = population.unstack()
korea_mdf
# Out:
#            2010     2020
# 광주광역시   1454636  1455048
# 대구광역시   2511676  2427954
# 대전광역시   1503664  1471040
# 부산광역시   2567910  3404423
# 서울특별시  10312345  9720846
# 인천광역시   2758296  2947217

# %%
korea_mdf.stack()
# Out:
# 광주광역시  2010     1454636
#        2020     1455048
# 대구광역시  2010     2511676
#        2020     2427954
# 대전광역시  2010     1503664
#        2020     1471040
# 부산광역시  2010     2567910
#        2020     3404423
# 서울특별시  2010    10312345
#        2020     9720846
# 인천광역시  2010     2758296
#        2020     2947217
# dtype: int64

# %%
male_tuple = [5111259, 4732275,
              1773170, 1668618,
              1390356, 1476813,
              1255245, 1198815,
              753648, 734441,
              721780, 720060]
male_tuple
# Out:
# [5111259,
#  4732275,
#  1773170,
#  1668618,
#  1390356,
#  1476813,
#  1255245,
#  1198815,
#  753648,
#  734441,
#  721780,
#  720060]

# %%
korea_mdf = pd.DataFrame({'총인구수': population, 
                          '남자인구수': male_tuple})
korea_mdf
# Out:
#                 총인구수    남자인구수
# 서울특별시 2010  10312345  5111259
#       2020   9720846  4732275
# 부산광역시 2010   2567910  1773170
#       2020   3404423  1668618
# 인천광역시 2010   2758296  1390356
#       2020   2947217  1476813
# 대구광역시 2010   2511676  1255245
#       2020   2427954  1198815
# 대전광역시 2010   1503664   753648
#       2020   1471040   734441
# 광주광역시 2010   1454636   721780
#       2020   1455048   720060

# %%
female_tuples = [5201286, 4988571,
                 1794740, 1735805,
                 1367940, 1470404,
                 1256431, 1229139,
                 750016, 736599,
                 732856, 734988]
female_tuples
# Out:
# [5201286,
#  4988571,
#  1794740,
#  1735805,
#  1367940,
#  1470404,
#  1256431,
#  1229139,
#  750016,
#  736599,
#  732856,
#  734988]

# %%
korea_mdf = pd.DataFrame({'총인구수': population, 
                          '남자인구수': male_tuple,
                          '여자인구수': female_tuples})
korea_mdf
# Out:
#                 총인구수    남자인구수    여자인구수
# 서울특별시 2010  10312345  5111259  5201286
#       2020   9720846  4732275  4988571
# 부산광역시 2010   2567910  1773170  1794740
#       2020   3404423  1668618  1735805
# 인천광역시 2010   2758296  1390356  1367940
#       2020   2947217  1476813  1470404
# 대구광역시 2010   2511676  1255245  1256431
#       2020   2427954  1198815  1229139
# 대전광역시 2010   1503664   753648   750016
#       2020   1471040   734441   736599
# 광주광역시 2010   1454636   721780   732856
#       2020   1455048   720060   734988

# %%
ratio = korea_mdf['남자인구수'] * 100 / korea_mdf['여자인구수']
ratio.unstack()
# Out:
#              2010        2020
# 광주광역시   98.488653   97.968946
# 대구광역시   99.905606   97.532907
# 대전광역시  100.484256   99.707032
# 부산광역시   98.798155   96.129346
# 서울특별시   98.269140   94.862336
# 인천광역시  101.638668  100.435867

# %%
korea_mdf = pd.DataFrame({'총인구수': population, 
                          '남자인구수': male_tuple,
                          '여자인구수': female_tuples,
                          '남여비율': ratio})
korea_mdf
# Out:
#                 총인구수    남자인구수    여자인구수        남여비율
# 서울특별시 2010  10312345  5111259  5201286   98.269140
#       2020   9720846  4732275  4988571   94.862336
# 부산광역시 2010   2567910  1773170  1794740   98.798155
#       2020   3404423  1668618  1735805   96.129346
# 인천광역시 2010   2758296  1390356  1367940  101.638668
#       2020   2947217  1476813  1470404  100.435867
# 대구광역시 2010   2511676  1255245  1256431   99.905606
#       2020   2427954  1198815  1229139   97.532907
# 대전광역시 2010   1503664   753648   750016  100.484256
#       2020   1471040   734441   736599   99.707032
# 광주광역시 2010   1454636   721780   732856   98.488653
#       2020   1455048   720060   734988   97.968946

# %% [markdown]
# #### 다중 인덱스 생성

# %%
df = pd.DataFrame(np.random.rand(6,3), 
                  index=[['a', 'a', 'b', 'b', 'c', 'c'], [1, 2, 1, 2, 1, 2]],
                  columns=['c1', 'c2', 'c3'])
df
# Out:
#            c1        c2        c3
# a 1  0.298428  0.243396  0.541325
#   2  0.489290  0.405014  0.561762
# b 1  0.787665  0.477510  0.137127
#   2  0.568881  0.279286  0.099550
# c 1  0.092323  0.934980  0.461238
#   2  0.472191  0.721426  0.267611

# %%
pd.MultiIndex.from_arrays([['a', 'a', 'b', 'b', 'c', 'c'], [1, 2, 1, 2, 1, 2]]) #배열로 인덱스 만들기
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('b', 1),
#             ('b', 2),
#             ('c', 1),
#             ('c', 2)],
#            )

# %%
pd.MultiIndex.from_tuples([('a', 1), ('a', 2), ('b', 1), ('b', 2), ('c', 1), ('c', 2)]) #튜플로 인덱스 만들기
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('b', 1),
#             ('b', 2),
#             ('c', 1),
#             ('c', 2)],
#            )

# %%
pd.MultiIndex.from_product([['a','b','c'], [1, 2]]) #곱으로 인덱스 만들기
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('b', 1),
#             ('b', 2),
#             ('c', 1),
#             ('c', 2)],
#            )

# %%
pd.MultiIndex(levels=[['a','b','c'], [1, 2]],
              codes=[[0, 0, 1, 1, 2, 2], [0, 1, 0, 1, 0, 1]]) #위치값의 인덱스를 코드로 나타냄
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('b', 1),
#             ('b', 2),
#             ('c', 1),
#             ('c', 2)],
#            )

# %%
population
# Out:
# 서울특별시  2010    10312345
#        2020     9720846
# 부산광역시  2010     2567910
#        2020     3404423
# 인천광역시  2010     2758296
#        2020     2947217
# 대구광역시  2010     2511676
#        2020     2427954
# 대전광역시  2010     1503664
#        2020     1471040
# 광주광역시  2010     1454636
#        2020     1455048
# dtype: int64

# %%
population.index.names = ['행정구역', '년도'] #인덱스 이름 설정하기
population.unstack()
# Out:
# 년도         2010     2020
# 행정구역
# 광주광역시   1454636  1455048
# 대구광역시   2511676  2427954
# 대전광역시   1503664  1471040
# 부산광역시   2567910  3404423
# 서울특별시  10312345  9720846
# 인천광역시   2758296  2947217

# %%
idx = pd.MultiIndex.from_product([['a','b','c'], [1,2]], 
                                 names=['name1','name2'])
col = pd.MultiIndex.from_product([['c1', 'c2', 'c3'], [1, 2]],
                                 names=['col_name1', 'col_name2'])
data = np.round(np.random.randn(6, 6), 2)
mdf = pd.DataFrame(data, index=idx, columns=col)
mdf
# Out:
# col_name1      c1          c2          c3
# col_name2       1     2     1     2     1     2
# name1 name2
# a     1     -0.91  0.75  1.20 -1.82  0.11 -1.44
#       2     -0.02  2.04  1.20  0.28 -0.25  0.72
# b     1     -0.10 -0.97  1.92  0.16  0.09 -0.83
#       2     -0.14  0.96 -1.07  1.34 -0.07 -0.52
# c     1     -1.32  1.33  0.53  0.96 -1.26 -0.01
#       2      0.14  1.02  2.39 -1.56 -0.02  0.27

# %%
mdf['c2']
# Out:
# col_name2       1     2
# name1 name2
# a     1      1.20 -1.82
#       2      1.20  0.28
# b     1      1.92  0.16
#       2     -1.07  1.34
# c     1      0.53  0.96
#       2      2.39 -1.56

# %% [markdown]
# #### 인덱싱 및 슬라이싱

# %%
population['인천광역시', 2010]
# Out:
# 2758296

# %%
population[:, 2010]
# Out:
# 행정구역
# 서울특별시    10312345
# 부산광역시     2567910
# 인천광역시     2758296
# 대구광역시     2511676
# 대전광역시     1503664
# 광주광역시     1454636
# dtype: int64

# %%
population[population > 3000000]
# Out:
# 행정구역   년도
# 서울특별시  2010    10312345
#        2020     9720846
# 부산광역시  2020     3404423
# dtype: int64

# %%
population[['대구광역시','대전광역시']]
# Out:
# 행정구역   년도
# 대구광역시  2010    2511676
#        2020    2427954
# 대전광역시  2010    1503664
#        2020    1471040
# dtype: int64

# %%
mdf
# Out:
# col_name1      c1          c2          c3
# col_name2       1     2     1     2     1     2
# name1 name2
# a     1     -0.91  0.75  1.20 -1.82  0.11 -1.44
#       2     -0.02  2.04  1.20  0.28 -0.25  0.72
# b     1     -0.10 -0.97  1.92  0.16  0.09 -0.83
#       2     -0.14  0.96 -1.07  1.34 -0.07 -0.52
# c     1     -1.32  1.33  0.53  0.96 -1.26 -0.01
#       2      0.14  1.02  2.39 -1.56 -0.02  0.27

# %%
mdf['c2', 1]
# Out:
# name1  name2
# a      1        1.20
#        2        1.20
# b      1        1.92
#        2       -1.07
# c      1        0.53
#        2        2.39
# Name: (c2, 1), dtype: float64

# %%
mdf.iloc[:3, :4] #정수 인덱스
# Out:
# col_name1      c1          c2
# col_name2       1     2     1     2
# name1 name2
# a     1     -0.91  0.75  1.20 -1.82
#       2     -0.02  2.04  1.20  0.28
# b     1     -0.10 -0.97  1.92  0.16

# %%
mdf.loc[:, ('c2', 1)]
# Out:
# name1  name2
# a      1        1.20
#        2        1.20
# b      1        1.92
#        2       -1.07
# c      1        0.53
#        2        2.39
# Name: (c2, 1), dtype: float64

# %%
idx_slice = pd.IndexSlice
mdf.loc[idx_slice[:, 2], idx_slice[:, 2]]
# Out:
# col_name1      c1    c2    c3
# col_name2       2     2     2
# name1 name2
# a     2      2.04  0.28  0.72
# b     2      0.96  1.34 -0.52
# c     2      1.02 -1.56  0.27

# %% [markdown]
# #### 다중 인덱스 재정렬

# %%
idx
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('b', 1),
#             ('b', 2),
#             ('c', 1),
#             ('c', 2)],
#            names=['name1', 'name2'])

# %%
korea_mdf
# Out:
#                 총인구수    남자인구수    여자인구수        남여비율
# 행정구역  년도
# 서울특별시 2010  10312345  5111259  5201286   98.269140
#       2020   9720846  4732275  4988571   94.862336
# 부산광역시 2010   2567910  1773170  1794740   98.798155
#       2020   3404423  1668618  1735805   96.129346
# 인천광역시 2010   2758296  1390356  1367940  101.638668
#       2020   2947217  1476813  1470404  100.435867
# 대구광역시 2010   2511676  1255245  1256431   99.905606
#       2020   2427954  1198815  1229139   97.532907
# 대전광역시 2010   1503664   753648   750016  100.484256
#       2020   1471040   734441   736599   99.707032
# 광주광역시 2010   1454636   721780   732856   98.488653
#       2020   1455048   720060   734988   97.968946

# %%
#korea_mdf['서울특별시':'인천광역시']
korea_mdf = korea_mdf.sort_index()
korea_mdf
# Out:
#                 총인구수    남자인구수    여자인구수        남여비율
# 행정구역  년도
# 광주광역시 2010   1454636   721780   732856   98.488653
#       2020   1455048   720060   734988   97.968946
# 대구광역시 2010   2511676  1255245  1256431   99.905606
#       2020   2427954  1198815  1229139   97.532907
# 대전광역시 2010   1503664   753648   750016  100.484256
#       2020   1471040   734441   736599   99.707032
# 부산광역시 2010   2567910  1773170  1794740   98.798155
#       2020   3404423  1668618  1735805   96.129346
# 서울특별시 2010  10312345  5111259  5201286   98.269140
#       2020   9720846  4732275  4988571   94.862336
# 인천광역시 2010   2758296  1390356  1367940  101.638668
#       2020   2947217  1476813  1470404  100.435867

# %%
korea_mdf['서울특별시':'인천광역시']
# Out:
#                 총인구수    남자인구수    여자인구수        남여비율
# 행정구역  년도
# 서울특별시 2010  10312345  5111259  5201286   98.269140
#       2020   9720846  4732275  4988571   94.862336
# 인천광역시 2010   2758296  1390356  1367940  101.638668
#       2020   2947217  1476813  1470404  100.435867

# %%
korea_mdf.unstack(level=0)
# Out:
#          총인구수                                                 남자인구수           \
# 행정구역    광주광역시    대구광역시    대전광역시    부산광역시     서울특별시    인천광역시   광주광역시    대구광역시
# 년도
# 2010  1454636  2511676  1503664  2567910  10312345  2758296  721780  1255245
# 2020  1455048  2427954  1471040  3404423   9720846  2947217  720060  1198815
#
#                        ...   여자인구수                                  남여비율  \
# 행정구역   대전광역시    부산광역시  ...   대전광역시    부산광역시    서울특별시    인천광역시      광주광역시
# 년도                     ...
# 2010  753648  1773170  ...  750016  1794740  5201286  1367940  98.488653
# 2020  734441  1668618  ...  736599  1735805  4988571  1470404  97.968946
#
#
# 행정구역      대구광역시       대전광역시      부산광역시      서울특별시       인천광역시
# 년도
# 2010  99.905606  100.484256  98.798155  98.269140  101.638668
# 2020  97.532907   99.707032  96.129346  94.862336  100.435867
#
# [2 rows x 24 columns]

# %%
korea_mdf.unstack(level=1)
# Out:
#            총인구수             남자인구수             여자인구수                 남여비율  \
# 년도         2010     2020     2010     2020     2010     2020        2010
# 행정구역
# 광주광역시   1454636  1455048   721780   720060   732856   734988   98.488653
# 대구광역시   2511676  2427954  1255245  1198815  1256431  1229139   99.905606
# 대전광역시   1503664  1471040   753648   734441   750016   736599  100.484256
# 부산광역시   2567910  3404423  1773170  1668618  1794740  1735805   98.798155
# 서울특별시  10312345  9720846  5111259  4732275  5201286  4988571   98.269140
# 인천광역시   2758296  2947217  1390356  1476813  1367940  1470404  101.638668
#
#
# 년도           2020
# 행정구역
# 광주광역시   97.968946
# 대구광역시   97.532907
# 대전광역시   99.707032
# 부산광역시   96.129346
# 서울특별시   94.862336
# 인천광역시  100.435867

# %%
korea_mdf.stack()
# Out:
# 행정구역   년도
# 광주광역시  2010  총인구수     1.454636e+06
#              남자인구수    7.217800e+05
#              여자인구수    7.328560e+05
#              남여비율     9.848865e+01
#        2020  총인구수     1.455048e+06
#              남자인구수    7.200600e+05
#              여자인구수    7.349880e+05
#              남여비율     9.796895e+01
# 대구광역시  2010  총인구수     2.511676e+06
#              남자인구수    1.255245e+06
#              여자인구수    1.256431e+06
#              남여비율     9.990561e+01
#        2020  총인구수     2.427954e+06
#              남자인구수    1.198815e+06
#              여자인구수    1.229139e+06
#              남여비율     9.753291e+01
# 대전광역시  2010  총인구수     1.503664e+06
#              남자인구수    7.536480e+05
#              여자인구수    7.500160e+05
#              남여비율     1.004843e+02
#        2020  총인구수     1.471040e+06
#              남자인구수    7.344410e+05
#              여자인구수    7.365990e+05
#              남여비율     9.970703e+01
# 부산광역시  2010  총인구수     2.567910e+06
#              남자인구수    1.773170e+06
# ...

# %%
korea_mdf
# Out:
#                 총인구수    남자인구수    여자인구수        남여비율
# 행정구역  년도
# 광주광역시 2010   1454636   721780   732856   98.488653
#       2020   1455048   720060   734988   97.968946
# 대구광역시 2010   2511676  1255245  1256431   99.905606
#       2020   2427954  1198815  1229139   97.532907
# 대전광역시 2010   1503664   753648   750016  100.484256
#       2020   1471040   734441   736599   99.707032
# 부산광역시 2010   2567910  1773170  1794740   98.798155
#       2020   3404423  1668618  1735805   96.129346
# 서울특별시 2010  10312345  5111259  5201286   98.269140
#       2020   9720846  4732275  4988571   94.862336
# 인천광역시 2010   2758296  1390356  1367940  101.638668
#       2020   2947217  1476813  1470404  100.435867

# %%
idx_flat = korea_mdf.reset_index(level=0)
idx_flat
# Out:
#        행정구역      총인구수    남자인구수    여자인구수        남여비율
# 년도
# 2010  광주광역시   1454636   721780   732856   98.488653
# 2020  광주광역시   1455048   720060   734988   97.968946
# 2010  대구광역시   2511676  1255245  1256431   99.905606
# 2020  대구광역시   2427954  1198815  1229139   97.532907
# 2010  대전광역시   1503664   753648   750016  100.484256
# 2020  대전광역시   1471040   734441   736599   99.707032
# 2010  부산광역시   2567910  1773170  1794740   98.798155
# 2020  부산광역시   3404423  1668618  1735805   96.129346
# 2010  서울특별시  10312345  5111259  5201286   98.269140
# 2020  서울특별시   9720846  4732275  4988571   94.862336
# 2010  인천광역시   2758296  1390356  1367940  101.638668
# 2020  인천광역시   2947217  1476813  1470404  100.435867

# %%
idx_flat = korea_mdf.reset_index(level=1)
idx_flat
# Out:
#          년도      총인구수    남자인구수    여자인구수        남여비율
# 행정구역
# 광주광역시  2010   1454636   721780   732856   98.488653
# 광주광역시  2020   1455048   720060   734988   97.968946
# 대구광역시  2010   2511676  1255245  1256431   99.905606
# 대구광역시  2020   2427954  1198815  1229139   97.532907
# 대전광역시  2010   1503664   753648   750016  100.484256
# 대전광역시  2020   1471040   734441   736599   99.707032
# 부산광역시  2010   2567910  1773170  1794740   98.798155
# 부산광역시  2020   3404423  1668618  1735805   96.129346
# 서울특별시  2010  10312345  5111259  5201286   98.269140
# 서울특별시  2020   9720846  4732275  4988571   94.862336
# 인천광역시  2010   2758296  1390356  1367940  101.638668
# 인천광역시  2020   2947217  1476813  1470404  100.435867

# %%
idx_flat = korea_mdf.reset_index(level=(0, 1))
idx_flat
# Out:
#      행정구역    년도      총인구수    남자인구수    여자인구수        남여비율
# 0   광주광역시  2010   1454636   721780   732856   98.488653
# 1   광주광역시  2020   1455048   720060   734988   97.968946
# 2   대구광역시  2010   2511676  1255245  1256431   99.905606
# 3   대구광역시  2020   2427954  1198815  1229139   97.532907
# 4   대전광역시  2010   1503664   753648   750016  100.484256
# 5   대전광역시  2020   1471040   734441   736599   99.707032
# 6   부산광역시  2010   2567910  1773170  1794740   98.798155
# 7   부산광역시  2020   3404423  1668618  1735805   96.129346
# 8   서울특별시  2010  10312345  5111259  5201286   98.269140
# 9   서울특별시  2020   9720846  4732275  4988571   94.862336
# 10  인천광역시  2010   2758296  1390356  1367940  101.638668
# 11  인천광역시  2020   2947217  1476813  1470404  100.435867

# %%
idx_flat.set_index(['행정구역', '년도'])
# Out:
#                 총인구수    남자인구수    여자인구수        남여비율
# 행정구역  년도
# 광주광역시 2010   1454636   721780   732856   98.488653
#       2020   1455048   720060   734988   97.968946
# 대구광역시 2010   2511676  1255245  1256431   99.905606
#       2020   2427954  1198815  1229139   97.532907
# 대전광역시 2010   1503664   753648   750016  100.484256
#       2020   1471040   734441   736599   99.707032
# 부산광역시 2010   2567910  1773170  1794740   98.798155
#       2020   3404423  1668618  1735805   96.129346
# 서울특별시 2010  10312345  5111259  5201286   98.269140
#       2020   9720846  4732275  4988571   94.862336
# 인천광역시 2010   2758296  1390356  1367940  101.638668
#       2020   2947217  1476813  1470404  100.435867

# %% [markdown]
# ## 데이터 연산

# %%
s = pd.Series(np.random.randint(0, 10, 5))
s
# Out:
# 0    2
# 1    0
# 2    2
# 3    8
# 4    1
# dtype: int32

# %%
df = pd.DataFrame(np.random.randint(0, 10, (3,3)),
                  columns=['A', 'B', 'C'])
df
# Out:
#    A  B  C
# 0  1  1  6
# 1  0  1  9
# 2  1  3  2

# %%
np.exp(s)
# Out:
# 0       7.389056
# 1       1.000000
# 2       7.389056
# 3    2980.957987
# 4       2.718282
# dtype: float64

# %%
np.cos(df * np.pi / 4)
# Out:
#           A         B             C
# 0  0.707107  0.707107 -1.836970e-16
# 1  1.000000  0.707107  7.071068e-01
# 2  0.707107 -0.707107  6.123234e-17

# %%
s1 = pd.Series([1, 3, 5, 7, 9], index=[0, 1, 2, 3, 4])
s2 = pd.Series([2, 4, 6, 8, 10], index=[1, 2, 3, 4, 5])
s1 + s2
# Out:
# 0     NaN
# 1     5.0
# 2     9.0
# 3    13.0
# 4    17.0
# 5     NaN
# dtype: float64

# %%
s1.add(s2, fill_value=0) #NaN 대신에 0을 넣는다
# Out:
# 0     1.0
# 1     5.0
# 2     9.0
# 3    13.0
# 4    17.0
# 5    10.0
# dtype: float64

# %%
df1 = pd.DataFrame(np.random.randint(0, 20, (3,3)),
                   columns=list('ACD'))
df1
# Out:
#     A   C   D
# 0   3   3  10
# 1  10   9   8
# 2   3  15   7

# %%
df2 = pd.DataFrame(np.random.randint(0, 20, (5,5)),
                   columns=list('BAECD'))
df2
# Out:
#     B   A   E   C   D
# 0  13  13  13   5   9
# 1  12   9   2  19   8
# 2  11   0   7  15   5
# 3  15  12  13   3  11
# 4  12  18   0   3  15

# %%
df1 + df2
# Out:
#       A   B     C     D   E
# 0  16.0 NaN   8.0  19.0 NaN
# 1  19.0 NaN  28.0  16.0 NaN
# 2   3.0 NaN  30.0  12.0 NaN
# 3   NaN NaN   NaN   NaN NaN
# 4   NaN NaN   NaN   NaN NaN

# %%
fvalue = df1.stack().mean()
df1.add(df2, fill_value = fvalue)
# Out:
#            A          B          C          D          E
# 0  16.000000  20.555556   8.000000  19.000000  20.555556
# 1  19.000000  19.555556  28.000000  16.000000   9.555556
# 2   3.000000  18.555556  30.000000  12.000000  14.555556
# 3  19.555556  22.555556  10.555556  18.555556  20.555556
# 4  25.555556  19.555556  10.555556  22.555556   7.555556

# %% [markdown]
# ### 연산자 범용 함수

# %% [markdown]
# #### add()

# %%
a = np.random.randint(1, 10, size=(3,3))
a
# Out:
# array([[5, 5, 7],
#        [9, 7, 4],
#        [3, 5, 2]])

# %%
a + a[0]
# Out:
# array([[10, 10, 14],
#        [14, 12, 11],
#        [ 8, 10,  9]])

# %%
df = pd.DataFrame(a, columns=list('ABC'))
df
# Out:
#    A  B  C
# 0  5  5  7
# 1  9  7  4
# 2  3  5  2

# %%
df + df.iloc[2]
# Out:
#     A   B  C
# 0   8  10  9
# 1  12  12  6
# 2   6  10  4

# %%
df.add(df.iloc[0])
# Out:
#     A   B   C
# 0  10  10  14
# 1  14  12  11
# 2   8  10   9

# %% [markdown]
# #### sub() / subtract()

# %%
a
# Out:
# array([[5, 5, 7],
#        [9, 7, 4],
#        [3, 5, 2]])

# %%
a - a[0]
# Out:
# array([[ 0,  0,  0],
#        [ 4,  2, -3],
#        [-2,  0, -5]])

# %%
df
# Out:
#    A  B  C
# 0  5  5  7
# 1  9  7  4
# 2  3  5  2

# %%
df - df.iloc[0]
# Out:
#    A  B  C
# 0  0  0  0
# 1  4  2 -3
# 2 -2  0 -5

# %%
df.sub(df.iloc[0])
# Out:
#    A  B  C
# 0  0  0  0
# 1  4  2 -3
# 2 -2  0 -5

# %%
df.subtract(df['B'], axis=0) #axis=0은 행방향으로 동작, 작업결과가 행으로 나타남, 책을 위로 쌓아 정리하는 것과 같음
# Out:
#    A  B  C
# 0  0  0  2
# 1  2  0 -3
# 2 -2  0 -3

# %% [markdown]
# #### mul() / multply()

# %%
a
# Out:
# array([[5, 5, 7],
#        [9, 7, 4],
#        [3, 5, 2]])

# %%
a * a[0]
# Out:
# array([[25, 25, 49],
#        [45, 35, 28],
#        [15, 25, 14]])

# %%
df
# Out:
#    A  B  C
# 0  5  5  7
# 1  9  7  4
# 2  3  5  2

# %%
df * df.iloc[1]
# Out:
#     A   B   C
# 0  45  35  28
# 1  81  49  16
# 2  27  35   8

# %%
df.mul(df.iloc[1])
# Out:
#     A   B   C
# 0  45  35  28
# 1  81  49  16
# 2  27  35   8

# %%
df.multiply(df.iloc[1])
# Out:
#     A   B   C
# 0  45  35  28
# 1  81  49  16
# 2  27  35   8

# %% [markdown]
# #### truediv() /  div() / divide() / floordiv()

# %%
a
# Out:
# array([[5, 5, 7],
#        [9, 7, 4],
#        [3, 5, 2]])

# %%
a / a[0]
# Out:
# array([[1.        , 1.        , 1.        ],
#        [1.8       , 1.4       , 0.57142857],
#        [0.6       , 1.        , 0.28571429]])

# %%
df
# Out:
#    A  B  C
# 0  5  5  7
# 1  9  7  4
# 2  3  5  2

# %%
df / df.iloc[0]
# Out:
#      A    B         C
# 0  1.0  1.0  1.000000
# 1  1.8  1.4  0.571429
# 2  0.6  1.0  0.285714

# %%
df.truediv(df.iloc[0])
# Out:
#      A    B         C
# 0  1.0  1.0  1.000000
# 1  1.8  1.4  0.571429
# 2  0.6  1.0  0.285714

# %%
df.div(df.iloc[1])
# Out:
#           A         B     C
# 0  0.555556  0.714286  1.75
# 1  1.000000  1.000000  1.00
# 2  0.333333  0.714286  0.50

# %%
df.divide(df.iloc[2])
# Out:
#           A    B    C
# 0  1.666667  1.0  3.5
# 1  3.000000  1.4  2.0
# 2  1.000000  1.0  1.0

# %%
a // a[0]
# Out:
# array([[1, 1, 1],
#        [1, 1, 0],
#        [0, 1, 0]], dtype=int32)

# %%
df.floordiv(df.iloc[0])
# Out:
#    A  B  C
# 0  1  1  1
# 1  1  1  0
# 2  0  1  0

# %% [markdown]
# #### mod()

# %%
a
# Out:
# array([[5, 5, 7],
#        [9, 7, 4],
#        [3, 5, 2]])

# %%
a % a[0]
# Out:
# array([[0, 0, 0],
#        [4, 2, 4],
#        [3, 0, 2]], dtype=int32)

# %%
df
# Out:
#    A  B  C
# 0  5  5  7
# 1  9  7  4
# 2  3  5  2

# %%
df.mod(df.iloc[0])
# Out:
#    A  B  C
# 0  0  0  0
# 1  4  2  4
# 2  3  0  2

# %% [markdown]
# #### pow()

# %%
a
# Out:
# array([[5, 5, 7],
#        [9, 7, 4],
#        [3, 5, 2]])

# %%
a ** a[0]
# Out:
# array([[  3125,   3125, 823543],
#        [ 59049,  16807,  16384],
#        [   243,   3125,    128]], dtype=int32)

# %%
df.pow(df.iloc[0])
# Out:
#        A      B       C
# 0   3125   3125  823543
# 1  59049  16807   16384
# 2    243   3125     128

# %%
row = df.iloc[0, ::2]
row
# Out:
# A    5
# C    7
# Name: 0, dtype: int32

# %%
df - row
# Out:
#      A   B    C
# 0  0.0 NaN  0.0
# 1  4.0 NaN -3.0
# 2 -2.0 NaN -5.0

# %% [markdown]
# ### 정렬(Sort)

# %%
s = pd.Series(range(5), index=['A', 'D', 'B', 'C', 'E'])
s
# Out:
# A    0
# D    1
# B    2
# C    3
# E    4
# dtype: int64

# %%
s.sort_index() #인덱스별 정렬
# Out:
# A    0
# B    2
# C    3
# D    1
# E    4
# dtype: int64

# %%
s.sort_values() #값으로 정렬
# Out:
# A    0
# D    1
# B    2
# C    3
# E    4
# dtype: int64

# %%
df = pd.DataFrame(np.random.randint(0, 10, (4,4)),
                  index = [2, 4, 1, 3],
                  columns = list('BDAC'))
df
# Out:
#    B  D  A  C
# 2  0  3  6  8
# 4  9  1  9  7
# 1  8  5  3  2
# 3  7  0  0  9

# %%
df.sort_index() #인덱스별 정렬
# Out:
#    B  D  A  C
# 1  8  5  3  2
# 2  0  3  6  8
# 3  7  0  0  9
# 4  9  1  9  7

# %%
df.sort_index(axis = 1) #축을 열로 지정하여 ABCD순으로 나옴
# Out:
#    A  B  C  D
# 2  6  0  8  3
# 4  9  9  7  1
# 1  3  8  2  5
# 3  0  7  9  0

# %%
# df.sort_values() 2차원이므로 column(열)을 하나 지정해줘야 함
df.sort_values(by = ['A', 'B']) # A 정렬 후 B 정렬
# Out:
#    B  D  A  C
# 3  7  0  0  9
# 1  8  5  3  2
# 2  0  3  6  8
# 4  9  1  9  7

# %%
df.sort_values(by = 'C')
# Out:
#    B  D  A  C
# 1  8  5  3  2
# 4  9  1  9  7
# 2  0  3  6  8
# 3  7  0  0  9

# %% [markdown]
# ### 순위(Ranking)

# %%
s = pd.Series([-2, 4, 7, 3, 0, 7, 5, -4, 2, 6])
s
# Out:
# 0   -2
# 1    4
# 2    7
# 3    3
# 4    0
# 5    7
# 6    5
# 7   -4
# 8    2
# 9    6
# dtype: int64

# %%
s.rank()
# Out:
# 0    2.0
# 1    6.0
# 2    9.5
# 3    5.0
# 4    3.0
# 5    9.5
# 6    7.0
# 7    1.0
# 8    4.0
# 9    8.0
# dtype: float64

# %%
s.rank(method = 'first') #테이블 내의 위치에 따라 순위 지정
# Out:
# 0     2.0
# 1     6.0
# 2     9.0
# 3     5.0
# 4     3.0
# 5    10.0
# 6     7.0
# 7     1.0
# 8     4.0
# 9     8.0
# dtype: float64

# %%
s.rank(method = 'max') #같은 값을 가지는 그룹을 높은 순위로 지정
# Out:
# 0     2.0
# 1     6.0
# 2    10.0
# 3     5.0
# 4     3.0
# 5    10.0
# 6     7.0
# 7     1.0
# 8     4.0
# 9     8.0
# dtype: float64

# %% [markdown]
# ### 고성능 연산

# %%
nrows, ncols = 100000, 100
df1, df2, df3, df4 = (pd.DataFrame(np.random.rand(nrows,ncols)) for i in range(4))

# %%
# %timeit df1 + df2 + df3 + df4
# Out:
# 140 ms ± 11.1 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit pd.eval('df1 + df2 + df3 + df4')
# Out:
# 61.1 ms ± 4.6 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit df1 * df2 / (-df3 * df4)
# Out:
# 223 ms ± 38.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit pd.eval('df1 * df2 / (-df3 * df4)')
# Out:
# 72.6 ms ± 3.75 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit (df1 < df2) & (df2 <= df3) & (df3 != df4)
# Out:
# 89.2 ms ± 1.81 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit pd.eval('(df1 < df2) & (df2 <= df3) & (df3 != df4)')
# Out:
# 67.6 ms ± 4.48 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
df = pd.DataFrame(np.random.rand(100000, 5), columns = ['A', 'B', 'C', 'D', 'E'])
df.head()
# Out:
#           A         B         C         D         E
# 0  0.026596  0.005120  0.182235  0.450722  0.233939
# 1  0.629269  0.379829  0.504189  0.288382  0.556950
# 2  0.782901  0.110480  0.550794  0.261152  0.638417
# 3  0.540238  0.396828  0.041025  0.916017  0.059042
# 4  0.908761  0.469786  0.683266  0.079409  0.246813

# %%
# %timeit df['A'] + df['B'] / df['C'] - df['D'] * df['E']
# Out:
# 5.89 ms ± 345 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit pd.eval('df.A + df.B /  df.C - df.D * df.E')
# Out:
# 7.37 ms ± 1.09 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit df.eval('A + B / C - D + E')
# Out:
# 8.91 ms ± 353 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
df.eval('R = A + B / C - D * E', inplace=True)
df.head()
# Out:
#           A         B         C         D         E          R
# 0  0.026596  0.005120  0.182235  0.450722  0.233939  -0.050750
# 1  0.629269  0.379829  0.504189  0.288382  0.556950   1.222002
# 2  0.782901  0.110480  0.550794  0.261152  0.638417   0.816761
# 3  0.540238  0.396828  0.041025  0.916017  0.059042  10.158906
# 4  0.908761  0.469786  0.683266  0.079409  0.246813   1.576721

# %%
col_mean = df.mean(1)
df['A'] + col_mean
# Out:
# 0        0.167906
# 1        1.226039
# 2        1.309651
# 3        2.558914
# 4        1.569553
#            ...
# 99995    0.989557
# 99996    1.015129
# 99997    1.798386
# 99998    1.511618
# 99999    2.665084
# Length: 100000, dtype: float64

# %%
 df.eval('A + @col_mean')
# Out:
# 0        0.167906
# 1        1.226039
# 2        1.309651
# 3        2.558914
# 4        1.569553
#            ...
# 99995    0.989557
# 99996    1.015129
# 99997    1.798386
# 99998    1.511618
# 99999    2.665084
# Length: 100000, dtype: float64

# %%
df[(df.A < 0.5) & (df.B < 0.5) & (df.C > 0.5)]
# Out:
#               A         B         C         D         E         R
# 6      0.190089  0.176580  0.887592  0.825360  0.165799  0.252187
# 9      0.274660  0.392059  0.625776  0.200532  0.784803  0.743799
# 16     0.113384  0.082193  0.601502  0.407853  0.803803 -0.077802
# 20     0.312091  0.110426  0.893007  0.440976  0.628618  0.158542
# 21     0.002552  0.473192  0.875897  0.948567  0.321811  0.237530
# ...         ...       ...       ...       ...       ...       ...
# 99958  0.242027  0.462620  0.739021  0.134546  0.306412  0.826791
# 99963  0.059059  0.227417  0.944015  0.689040  0.047744  0.267065
# 99984  0.289829  0.380063  0.820176  0.458024  0.099847  0.707489
# 99989  0.407831  0.117360  0.889732  0.388032  0.154217  0.479894
# 99992  0.257684  0.216059  0.638898  0.528045  0.936445  0.101373
#
# [12486 rows x 6 columns]

# %%
pd.eval('df[(df.A < 0.5) & (df.B < 0.5) & (df.C > 0.5)]')
# Out:
#               A         B         C         D         E         R
# 6      0.190089  0.176580  0.887592  0.825360  0.165799  0.252187
# 9      0.274660  0.392059  0.625776  0.200532  0.784803  0.743799
# 16     0.113384  0.082193  0.601502  0.407853  0.803803 -0.077802
# 20     0.312091  0.110426  0.893007  0.440976  0.628618  0.158542
# 21     0.002552  0.473192  0.875897  0.948567  0.321811  0.237530
# ...         ...       ...       ...       ...       ...       ...
# 99958  0.242027  0.462620  0.739021  0.134546  0.306412  0.826791
# 99963  0.059059  0.227417  0.944015  0.689040  0.047744  0.267065
# 99984  0.289829  0.380063  0.820176  0.458024  0.099847  0.707489
# 99989  0.407831  0.117360  0.889732  0.388032  0.154217  0.479894
# 99992  0.257684  0.216059  0.638898  0.528045  0.936445  0.101373
#
# [12486 rows x 6 columns]

# %%
df.query('(A < 0.5) and (B < 0.5) and (C > 0.5)') #query는 eval보다 간단히 표현
# Out:
#               A         B         C         D         E         R
# 6      0.190089  0.176580  0.887592  0.825360  0.165799  0.252187
# 9      0.274660  0.392059  0.625776  0.200532  0.784803  0.743799
# 16     0.113384  0.082193  0.601502  0.407853  0.803803 -0.077802
# 20     0.312091  0.110426  0.893007  0.440976  0.628618  0.158542
# 21     0.002552  0.473192  0.875897  0.948567  0.321811  0.237530
# ...         ...       ...       ...       ...       ...       ...
# 99958  0.242027  0.462620  0.739021  0.134546  0.306412  0.826791
# 99963  0.059059  0.227417  0.944015  0.689040  0.047744  0.267065
# 99984  0.289829  0.380063  0.820176  0.458024  0.099847  0.707489
# 99989  0.407831  0.117360  0.889732  0.388032  0.154217  0.479894
# 99992  0.257684  0.216059  0.638898  0.528045  0.936445  0.101373
#
# [12486 rows x 6 columns]

# %%
col_means = df['D'].mean()
df[(df.A < col_means) & (df.B < col_means)]
# Out:
#               A         B         C         D         E          R
# 0      0.026596  0.005120  0.182235  0.450722  0.233939  -0.050750
# 5      0.200746  0.424483  0.179290  0.867477  0.438776   2.187698
# 6      0.190089  0.176580  0.887592  0.825360  0.165799   0.252187
# 9      0.274660  0.392059  0.625776  0.200532  0.784803   0.743799
# 16     0.113384  0.082193  0.601502  0.407853  0.803803  -0.077802
# ...         ...       ...       ...       ...       ...        ...
# 99972  0.105260  0.410750  0.177232  0.778181  0.154832   2.302354
# 99977  0.467582  0.311198  0.030542  0.749820  0.799018  10.057769
# 99984  0.289829  0.380063  0.820176  0.458024  0.099847   0.707489
# 99989  0.407831  0.117360  0.889732  0.388032  0.154217   0.479894
# 99992  0.257684  0.216059  0.638898  0.528045  0.936445   0.101373
#
# [24786 rows x 6 columns]

# %%
df.query('A < @col_means and B < @col_means') # @는 외부변수 접근표시
# Out:
#               A         B         C         D         E          R
# 0      0.026596  0.005120  0.182235  0.450722  0.233939  -0.050750
# 5      0.200746  0.424483  0.179290  0.867477  0.438776   2.187698
# 6      0.190089  0.176580  0.887592  0.825360  0.165799   0.252187
# 9      0.274660  0.392059  0.625776  0.200532  0.784803   0.743799
# 16     0.113384  0.082193  0.601502  0.407853  0.803803  -0.077802
# ...         ...       ...       ...       ...       ...        ...
# 99972  0.105260  0.410750  0.177232  0.778181  0.154832   2.302354
# 99977  0.467582  0.311198  0.030542  0.749820  0.799018  10.057769
# 99984  0.289829  0.380063  0.820176  0.458024  0.099847   0.707489
# 99989  0.407831  0.117360  0.889732  0.388032  0.154217   0.479894
# 99992  0.257684  0.216059  0.638898  0.528045  0.936445   0.101373
#
# [24786 rows x 6 columns]

# %% [markdown]
# ## 데이터 결합

# %% [markdown]
# ### Concat() / Append()

# %%
s1 = pd.Series(['a', 'b'], index=[1, 2])
s2 = pd.Series(['c', 'd'], index=[3, 4])
pd.concat([s1, s2])
# Out:
# 1    a
# 2    b
# 3    c
# 4    d
# dtype: object

# %%
def create_df(cols, idx):
    data = {c: [str(c.lower()) + str(i) for i in idx] for c in cols}
    return pd.DataFrame(data, idx)

# %%
df1 = create_df('AB', [1, 2])
df1
# Out:
#     A   B
# 1  a1  b1
# 2  a2  b2

# %%
df2 = create_df('AB', [3, 4])
df2
# Out:
#     A   B
# 3  a3  b3
# 4  a4  b4

# %%
pd.concat([df1, df2])
# Out:
#     A   B
# 1  a1  b1
# 2  a2  b2
# 3  a3  b3
# 4  a4  b4

# %%
df3 = create_df('AB', [0, 1])
df3
# Out:
#     A   B
# 0  a0  b0
# 1  a1  b1

# %%
df4 = create_df('CD', [0, 1])
df4
# Out:
#     C   D
# 0  c0  d0
# 1  c1  d1

# %%
pd.concat([df3, df4])
# Out:
#      A    B    C    D
# 0   a0   b0  NaN  NaN
# 1   a1   b1  NaN  NaN
# 0  NaN  NaN   c0   d0
# 1  NaN  NaN   c1   d1

# %%
#pd.concat([df1, df3], verify_integrity=True) #오버랩되기 때문에 error 발생

# %%
pd.concat([df1, df3], ignore_index=True) #강제로 합치기
# Out:
#     A   B
# 0  a1  b1
# 1  a2  b2
# 2  a0  b0
# 3  a1  b1

# %%
pd.concat([df1, df3], keys=['X', 'Y'])
# Out:
#       A   B
# X 1  a1  b1
#   2  a2  b2
# Y 0  a0  b0
#   1  a1  b1

# %%
df5 = create_df('ABC', [1, 2])
df6 = create_df('BCD', [3, 4])
pd.concat([df5, df6])
# Out:
#      A   B   C    D
# 1   a1  b1  c1  NaN
# 2   a2  b2  c2  NaN
# 3  NaN  b3  c3   d3
# 4  NaN  b4  c4   d4

# %%
pd.concat([df5, df6], join='inner')
# Out:
#     B   C
# 1  b1  c1
# 2  b2  c2
# 3  b3  c3
# 4  b4  c4

# %%
df5.append(df6)
# Out:
#      A   B   C    D
# 1   a1  b1  c1  NaN
# 2   a2  b2  c2  NaN
# 3  NaN  b3  c3   d3
# 4  NaN  b4  c4   d4

# %%
pd.concat([df3, df4])
# Out:
#      A    B    C    D
# 0   a0   b0  NaN  NaN
# 1   a1   b1  NaN  NaN
# 0  NaN  NaN   c0   d0
# 1  NaN  NaN   c1   d1

# %%
pd.concat([df3, df4], axis=1) #axis=1은 작업 결과가 옆으로 나타남
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1

# %% [markdown]
# ### 병합과 조인

# %%
df1 = pd.DataFrame({'학생': ['홍길동', '이순신', '임꺽정', '김유신'],
                    '학과': ['경영학과', '교육학과', '컴퓨터학과', '통계학과']})
df1
# Out:
#     학생     학과
# 0  홍길동   경영학과
# 1  이순신   교육학과
# 2  임꺽정  컴퓨터학과
# 3  김유신   통계학과

# %%
df2 = pd.DataFrame({'학생': ['홍길동', '이순신', '임꺽정', '김유신'],
                    '입학년도': [2012, 2016, 2019, 2020]})
df2
# Out:
#     학생  입학년도
# 0  홍길동  2012
# 1  이순신  2016
# 2  임꺽정  2019
# 3  김유신  2020

# %%
df3 = pd.merge(df1, df2) #데이터프레임 병합
df3
# Out:
#     학생     학과  입학년도
# 0  홍길동   경영학과  2012
# 1  이순신   교육학과  2016
# 2  임꺽정  컴퓨터학과  2019
# 3  김유신   통계학과  2020

# %%
df4 = pd.DataFrame({'학과': ['경영학과', '교육학과', '켬퓨터학과', '통계학과'],
                    '학과장': ['황희', '장영실', '안창호', '정약용']})
df4
# Out:
#       학과  학과장
# 0   경영학과   황희
# 1   교육학과  장영실
# 2  켬퓨터학과  안창호
# 3   통계학과  정약용

# %%
pd.merge(df3, df4)
# Out:
#     학생    학과  입학년도  학과장
# 0  홍길동  경영학과  2012   황희
# 1  이순신  교육학과  2016  장영실
# 2  김유신  통계학과  2020  정약용

# %%
df5 = pd.DataFrame({'학과': ['경영학과', '교육학과', '교육학과', '컴퓨터학과', '컴퓨터학과', '통계학과'],
                    '과목': ['경영개론', '기초수학', '물리학', '프로그래밍', '운영체제', '확률론']})
df5
# Out:
#       학과     과목
# 0   경영학과   경영개론
# 1   교육학과   기초수학
# 2   교육학과    물리학
# 3  컴퓨터학과  프로그래밍
# 4  컴퓨터학과   운영체제
# 5   통계학과    확률론

# %%
pd.merge(df1, df5) #학과를 기준으로 병합
# Out:
#     학생     학과     과목
# 0  홍길동   경영학과   경영개론
# 1  이순신   교육학과   기초수학
# 2  이순신   교육학과    물리학
# 3  임꺽정  컴퓨터학과  프로그래밍
# 4  임꺽정  컴퓨터학과   운영체제
# 5  김유신   통계학과    확률론

# %%
pd.merge(df1, df2, on='학생') #on은 학생을 기준으로 한 것
# Out:
#     학생     학과  입학년도
# 0  홍길동   경영학과  2012
# 1  이순신   교육학과  2016
# 2  임꺽정  컴퓨터학과  2019
# 3  김유신   통계학과  2020

# %%
df6 = pd.DataFrame({'이름': ['홍길동', '이순신', '임꺽정', '김유신'],
                    '성적': ['A', 'A+', 'B', 'A+']})
df6
# Out:
#     이름  성적
# 0  홍길동   A
# 1  이순신  A+
# 2  임꺽정   B
# 3  김유신  A+

# %%
#pd.merge(df1, df6)
pd.merge(df1, df6, left_on='학생', right_on='이름')
# Out:
#     학생     학과   이름  성적
# 0  홍길동   경영학과  홍길동   A
# 1  이순신   교육학과  이순신  A+
# 2  임꺽정  컴퓨터학과  임꺽정   B
# 3  김유신   통계학과  김유신  A+

# %%
pd.merge(df1, df6, left_on='학생', right_on='이름').drop('이름', axis=1)
# Out:
#     학생     학과  성적
# 0  홍길동   경영학과   A
# 1  이순신   교육학과  A+
# 2  임꺽정  컴퓨터학과   B
# 3  김유신   통계학과  A+

# %%
mdf1 = df1.set_index('학생')
mdf2 = df2.set_index('학생')

# %%
mdf1
# Out:
#         학과
# 학생
# 홍길동   경영학과
# 이순신   교육학과
# 임꺽정  컴퓨터학과
# 김유신   통계학과

# %%
mdf2
# Out:
#      입학년도
# 학생
# 홍길동  2012
# 이순신  2016
# 임꺽정  2019
# 김유신  2020

# %%
pd.merge(mdf1, mdf2, left_index=True, right_index=True)
# Out:
#         학과  입학년도
# 학생
# 홍길동   경영학과  2012
# 이순신   교육학과  2016
# 임꺽정  컴퓨터학과  2019
# 김유신   통계학과  2020

# %%
mdf1.join(mdf2)
# Out:
#         학과  입학년도
# 학생
# 홍길동   경영학과  2012
# 이순신   교육학과  2016
# 임꺽정  컴퓨터학과  2019
# 김유신   통계학과  2020

# %%
pd.merge(mdf1, df6, left_index=True, right_on='이름')
# Out:
#       학과   이름  성적
# 0   경영학과  홍길동   A
# 1   교육학과  이순신  A+
# 2  컴퓨터학과  임꺽정   B
# 3   통계학과  김유신  A+

# %%
df7 = pd.DataFrame({'이름': ['홍길동', '이순신', '임꺽정'],
                    '주문음식': ['햄버거', '피자', '짜장면']})
df7
# Out:
#     이름 주문음식
# 0  홍길동  햄버거
# 1  이순신   피자
# 2  임꺽정  짜장면

# %%
df8 = pd.DataFrame({'이름': ['홍길동', '이순신', '김유신'],
                    '주문음료': ['콜라', '사이다', '커피']})
df8
# Out:
#     이름 주문음료
# 0  홍길동   콜라
# 1  이순신  사이다
# 2  김유신   커피

# %%
pd.merge(df7, df8)
# Out:
#     이름 주문음식 주문음료
# 0  홍길동  햄버거   콜라
# 1  이순신   피자  사이다

# %%
pd.merge(df7, df8, how='inner')
# Out:
#     이름 주문음식 주문음료
# 0  홍길동  햄버거   콜라
# 1  이순신   피자  사이다

# %%
pd.merge(df7, df8, how='outer') #outer는 다 포함
# Out:
#     이름 주문음식 주문음료
# 0  홍길동  햄버거   콜라
# 1  이순신   피자  사이다
# 2  임꺽정  짜장면  NaN
# 3  김유신  NaN   커피

# %%
pd.merge(df7, df8, how='left') #df7가 기준
# Out:
#     이름 주문음식 주문음료
# 0  홍길동  햄버거   콜라
# 1  이순신   피자  사이다
# 2  임꺽정  짜장면  NaN

# %%
pd.merge(df7, df8, how='right') #df8이 기준
# Out:
#     이름 주문음식 주문음료
# 0  홍길동  햄버거   콜라
# 1  이순신   피자  사이다
# 2  김유신  NaN   커피

# %%
df9 = pd.DataFrame({'이름':['홍길동', '이순신', '임꺽정', '김유신'],
                    '순위':[3,2,4,1]})
df9
# Out:
#     이름  순위
# 0  홍길동   3
# 1  이순신   2
# 2  임꺽정   4
# 3  김유신   1

# %%
df10= pd.DataFrame({'이름':['홍길동', '이순신', '임꺽정', '김유신'],
                    '순위':[4,1,3,2]})
df10
# Out:
#     이름  순위
# 0  홍길동   4
# 1  이순신   1
# 2  임꺽정   3
# 3  김유신   2

# %%
pd.merge(df9, df10, on='이름', suffixes=["_인기", "_성적"])
# Out:
#     이름  순위_인기  순위_성적
# 0  홍길동      3      4
# 1  이순신      2      1
# 2  임꺽정      4      3
# 3  김유신      1      2

# %% [markdown]
# ## 데이터 집계와 그룹 연산

# %% [markdown]
# #### 집계 연산(Aggregation)

# %%
df = pd.DataFrame([[1, 1.2, np.nan],
              [2.4, 5.5, 4.2],
              [np.nan, np.nan, np.nan],
              [0.44, -3.1, -4.1]],
             index=[1, 2, 3, 4],
             columns=['A','B','C'])
df
# Out:
#       A    B    C
# 1  1.00  1.2  NaN
# 2  2.40  5.5  4.2
# 3   NaN  NaN  NaN
# 4  0.44 -3.1 -4.1

# %%
df.head(2) #앞부분 2행 출력
# Out:
#      A    B    C
# 1  1.0  1.2  NaN
# 2  2.4  5.5  4.2

# %%
df.tail(2) #뒷부분 2행 출력
# Out:
#       A    B    C
# 3   NaN  NaN  NaN
# 4  0.44 -3.1 -4.1

# %%
df.describe()
# Out:
#               A     B         C
# count  3.000000  3.00  2.000000
# mean   1.280000  1.20  0.050000
# std    1.009554  4.30  5.868986
# min    0.440000 -3.10 -4.100000
# 25%    0.720000 -0.95 -2.025000
# 50%    1.000000  1.20  0.050000
# 75%    1.700000  3.35  2.125000
# max    2.400000  5.50  4.200000

# %%
print(df)
print(np.argmin(df), np.argmax(df)) #열방향으로 최소값, 최대값의 색인 위치 argmin,argmax
# Out:
#       A    B    C
# 1  1.00  1.2  NaN
# 2  2.40  5.5  4.2
# 3   NaN  NaN  NaN
# 4  0.44 -3.1 -4.1
# 2 2

# %%
print(df)
print(df.idxmin()) #행방향으로 최소값, 최대값의 색인 위치 idxmin, idxmax
print(df.idxmax())
# Out:
#       A    B    C
# 1  1.00  1.2  NaN
# 2  2.40  5.5  4.2
# 3   NaN  NaN  NaN
# 4  0.44 -3.1 -4.1
# A    4
# B    4
# C    4
# dtype: int64
# A    2
# B    2
# C    2
# dtype: int64

# %%
print(df)
print(df.std()) #표본분산
print(df.var()) #분산
# Out:
#       A    B    C
# 1  1.00  1.2  NaN
# 2  2.40  5.5  4.2
# 3   NaN  NaN  NaN
# 4  0.44 -3.1 -4.1
# A    1.009554
# B    4.300000
# C    5.868986
# dtype: float64
# A     1.0192
# B    18.4900
# C    34.4450
# dtype: float64

# %%
print(df)
print(df.skew()) #왜도
print(df.kurt()) #첨도
# Out:
#       A    B    C
# 1  1.00  1.2  NaN
# 2  2.40  5.5  4.2
# 3   NaN  NaN  NaN
# 4  0.44 -3.1 -4.1
# A    1.15207
# B    0.00000
# C        NaN
# dtype: float64
# A   NaN
# B   NaN
# C   NaN
# dtype: float64

# %%
print(df)
print(df.sum()) #합, NaN 스킵
print(df.cumsum()) #누적합
# Out:
#       A    B    C
# 1  1.00  1.2  NaN
# 2  2.40  5.5  4.2
# 3   NaN  NaN  NaN
# 4  0.44 -3.1 -4.1
# A    3.84
# B    3.60
# C    0.10
# dtype: float64
#       A    B    C
# 1  1.00  1.2  NaN
# 2  3.40  6.7  4.2
# 3   NaN  NaN  NaN
# 4  3.84  3.6  0.1

# %%
print(df)
print(df.prod()) #곱
print(df.cumprod()) #누적 곱
# Out:
#       A    B    C
# 1  1.00  1.2  NaN
# 2  2.40  5.5  4.2
# 3   NaN  NaN  NaN
# 4  0.44 -3.1 -4.1
# A     1.056
# B   -20.460
# C   -17.220
# dtype: float64
#        A      B      C
# 1  1.000   1.20    NaN
# 2  2.400   6.60   4.20
# 3    NaN    NaN    NaN
# 4  1.056 -20.46 -17.22

# %%
df.diff()
# Out:
#      A    B   C
# 1  NaN  NaN NaN
# 2  1.4  4.3 NaN
# 3  NaN  NaN NaN
# 4  NaN  NaN NaN

# %%
df.quantile()
# Out:
# A    1.00
# B    1.20
# C    0.05
# Name: 0.5, dtype: float64

# %%
df.pct_change()
# Out:
#           A         B        C
# 1       NaN       NaN      NaN
# 2  1.400000  3.583333      NaN
# 3  0.000000  0.000000  0.00000
# 4 -0.816667 -1.563636 -1.97619

# %%
df.corr() #상관관계 분석
# Out:
#           A         B    C
# A  1.000000  0.970725  1.0
# B  0.970725  1.000000  1.0
# C  1.000000  1.000000  1.0

# %%
df.corrwith(df.B) #B값을 기준으로 상관관계 분석
# Out:
# A    0.970725
# B    1.000000
# C    1.000000
# dtype: float64

# %%
df.cov() #공분산
# Out:
#         A       B       C
# A  1.0192   4.214   8.134
# B  4.2140  18.490  35.690
# C  8.1340  35.690  34.445

# %%
df['B'].unique()
# Out:
# array([ 1.2,  5.5,  nan, -3.1])

# %%
df['A'].value_counts()
# Out:
# 0.44    1
# 2.40    1
# 1.00    1
# Name: A, dtype: int64

# %% [markdown]
# ### GroupBy 연산

# %%
df = pd.DataFrame({'c1': ['a', 'a', 'b', 'b', 'c','d', 'b'],
                   'c2': ['A', 'B', 'B', 'A', 'D', 'C', 'C'],
                   'c3': np.random.randint(7),
                   'c4': np.random.random(7)})
df
# Out:
#   c1 c2  c3        c4
# 0  a  A   6  0.780286
# 1  a  B   6  0.773745
# 2  b  B   6  0.191113
# 3  b  A   6  0.609423
# 4  c  D   6  0.528659
# 5  d  C   6  0.331174
# 6  b  C   6  0.490646

# %%
df.dtypes
# Out:
# c1     object
# c2     object
# c3      int64
# c4    float64
# dtype: object

# %%
df['c3'].groupby(df['c1']).mean() #c1을 기준으로 c3의 mean값 계산
# Out:
# c1
# a    6
# b    6
# c    6
# d    6
# Name: c3, dtype: int64

# %%
df['c4'].groupby(df['c2']).std() #c2를 기준으로 c4의 표준편차 계산
# Out:
# c2
# A    0.120818
# B    0.411983
# C    0.112764
# D         NaN
# Name: c4, dtype: float64

# %%
df['c4'].groupby([df['c1'], df['c2']]).mean() #c1을 첫번째, c2를 두번째 기준으로 c4의 평균 계산
# Out:
# c1  c2
# a   A     0.780286
#     B     0.773745
# b   A     0.609423
#     B     0.191113
#     C     0.490646
# c   D     0.528659
# d   C     0.331174
# Name: c4, dtype: float64

# %%
df['c4'].groupby([df['c1'], df['c2']]).mean().unstack()
# Out:
# c2         A         B         C         D
# c1
# a   0.780286  0.773745       NaN       NaN
# b   0.609423  0.191113  0.490646       NaN
# c        NaN       NaN       NaN  0.528659
# d        NaN       NaN  0.331174       NaN

# %%
df.groupby('c1').mean() #c1을 기준으로 평균계산
# Out:
#     c3        c4
# c1
# a    6  0.777015
# b    6  0.430394
# c    6  0.528659
# d    6  0.331174

# %%
df.groupby(['c1', 'c2']).mean() #c1,c2를 기준으로 평균계산
# Out:
#        c3        c4
# c1 c2
# a  A    6  0.780286
#    B    6  0.773745
# b  A    6  0.609423
#    B    6  0.191113
#    C    6  0.490646
# c  D    6  0.528659
# d  C    6  0.331174

# %%
df.groupby(['c1', 'c2']).size() #c1,c2 기준으로 크기 계산
# Out:
# c1  c2
# a   A     1
#     B     1
# b   A     1
#     B     1
#     C     1
# c   D     1
# d   C     1
# dtype: int64

# %%
df.groupby('c1')

# %%
for c1, group in df.groupby('c1'):
    print(c1)
    print(group)
# Out:
# a
#   c1 c2  c3        c4
# 0  a  A   6  0.780286
# 1  a  B   6  0.773745
# b
#   c1 c2  c3        c4
# 2  b  B   6  0.191113
# 3  b  A   6  0.609423
# 6  b  C   6  0.490646
# c
#   c1 c2  c3        c4
# 4  c  D   6  0.528659
# d
#   c1 c2  c3        c4
# 5  d  C   6  0.331174

# %%
for (c1,c2), group in df.groupby(['c1','c2']):
    print((c1,c2))
    print(group)
# Out:
# ('a', 'A')
#   c1 c2  c3        c4
# 0  a  A   6  0.780286
# ('a', 'B')
#   c1 c2  c3        c4
# 1  a  B   6  0.773745
# ('b', 'A')
#   c1 c2  c3        c4
# 3  b  A   6  0.609423
# ('b', 'B')
#   c1 c2  c3        c4
# 2  b  B   6  0.191113
# ('b', 'C')
#   c1 c2  c3        c4
# 6  b  C   6  0.490646
# ('c', 'D')
#   c1 c2  c3        c4
# 4  c  D   6  0.528659
# ('d', 'C')
#   c1 c2  c3        c4
# 5  d  C   6  0.331174

# %%
df.groupby(['c1', 'c2'])[['c4']].mean()
# Out:
#              c4
# c1 c2
# a  A   0.780286
#    B   0.773745
# b  A   0.609423
#    B   0.191113
#    C   0.490646
# c  D   0.528659
# d  C   0.331174

# %%
df.groupby('c1')['c3'].quantile()
# Out:
# c1
# a    6.0
# b    6.0
# c    6.0
# d    6.0
# Name: c3, dtype: float64

# %%
df.groupby('c1')['c3'].count()
# Out:
# c1
# a    2
# b    3
# c    1
# d    1
# Name: c3, dtype: int64

# %%
df.groupby('c1')['c4'].median()
# Out:
# c1
# a    0.777015
# b    0.490646
# c    0.528659
# d    0.331174
# Name: c4, dtype: float64

# %%
df.groupby('c1')['c4'].std()
# Out:
# c1
# a    0.004625
# b    0.215566
# c         NaN
# d         NaN
# Name: c4, dtype: float64

# %%
df.groupby(['c1', 'c2'])['c4'].agg(['mean', 'min', 'max']) #c1과 c2를 기준으로 c4에 대한 전체집계값을 여러 개 출력
# Out:
#            mean       min       max
# c1 c2
# a  A   0.780286  0.780286  0.780286
#    B   0.773745  0.773745  0.773745
# b  A   0.609423  0.609423  0.609423
#    B   0.191113  0.191113  0.191113
#    C   0.490646  0.490646  0.490646
# c  D   0.528659  0.528659  0.528659
# d  C   0.331174  0.331174  0.331174

# %%
df.groupby(['c1', 'c2'], as_index=False)['c4'].mean() #인덱스 사라지고 하나의 컬럼으로 표시됨
# Out:
#   c1 c2        c4
# 0  a  A  0.780286
# 1  a  B  0.773745
# 2  b  A  0.609423
# 3  b  B  0.191113
# 4  b  C  0.490646
# 5  c  D  0.528659
# 6  d  C  0.331174

# %%
df.groupby(['c1', 'c2'], group_keys=False)['c4'].mean()
# Out:
# c1  c2
# a   A     0.780286
#     B     0.773745
# b   A     0.609423
#     B     0.191113
#     C     0.490646
# c   D     0.528659
# d   C     0.331174
# Name: c4, dtype: float64

# %%
def top(df, n=3, column='c1'):
    return df.sort_values(by=column)[-n:]

top(df, n=5) #c1을 기준으로 top 5 출력
# Out:
#   c1 c2  c3        c4
# 2  b  B   6  0.191113
# 3  b  A   6  0.609423
# 6  b  C   6  0.490646
# 4  c  D   6  0.528659
# 5  d  C   6  0.331174

# %%
top(df, n=6, column='c4') #c4를 기준으로 값이 큰 6개 행 출력
# Out:
#   c1 c2  c3        c4
# 5  d  C   6  0.331174
# 6  b  C   6  0.490646
# 4  c  D   6  0.528659
# 3  b  A   6  0.609423
# 1  a  B   6  0.773745
# 0  a  A   6  0.780286

# %%
df.groupby('c1').apply(top)
# Out:
#      c1 c2  c3        c4
# c1
# a  0  a  A   6  0.780286
#    1  a  B   6  0.773745
# b  2  b  B   6  0.191113
#    3  b  A   6  0.609423
#    6  b  C   6  0.490646
# c  4  c  D   6  0.528659
# d  5  d  C   6  0.331174

# %% [markdown]
# ### 피벗 테이블(Pivot Table)

# %%
df.pivot_table(['c3', 'c4'],
               index=['c1'],
               columns=['c2'])
# Out:
#      c3                       c4
# c2    A    B    C    D         A         B         C         D
# c1
# a   6.0  6.0  NaN  NaN  0.780286  0.773745       NaN       NaN
# b   6.0  6.0  6.0  NaN  0.609423  0.191113  0.490646       NaN
# c   NaN  NaN  NaN  6.0       NaN       NaN       NaN  0.528659
# d   NaN  NaN  6.0  NaN       NaN       NaN  0.331174       NaN

# %%
df.pivot_table(['c3', 'c4'],
               index=['c1'],
               columns=['c2'],
               margins=True) #margin은 부분합 총계
# Out:
#       c3                           c4
# c2     A    B    C    D All         A         B         C         D       All
# c1
# a    6.0  6.0  NaN  NaN   6  0.780286  0.773745       NaN       NaN  0.777015
# b    6.0  6.0  6.0  NaN   6  0.609423  0.191113  0.490646       NaN  0.430394
# c    NaN  NaN  NaN  6.0   6       NaN       NaN       NaN  0.528659  0.528659
# d    NaN  NaN  6.0  NaN   6       NaN       NaN  0.331174       NaN  0.331174
# All  6.0  6.0  6.0  6.0   6  0.694855  0.482429  0.410910  0.528659  0.529292

# %%
df.pivot_table(['c3', 'c4'],
               index=['c1'],
               columns=['c2'],
               margins=True,
               aggfunc=sum)
# Out:
#        c3                             c4                                \
# c2      A     B     C    D All         A         B         C         D
# c1
# a     6.0   6.0   NaN  NaN  12  0.780286  0.773745       NaN       NaN
# b     6.0   6.0   6.0  NaN  18  0.609423  0.191113  0.490646       NaN
# c     NaN   NaN   NaN  6.0   6       NaN       NaN       NaN  0.528659
# d     NaN   NaN   6.0  NaN   6       NaN       NaN  0.331174       NaN
# All  12.0  12.0  12.0  6.0  42  1.389709  0.964858  0.821820  0.528659
#
#
# c2        All
# c1
# a    1.554031
# b    1.291183
# c    0.528659
# d    0.331174
# All  3.705047

# %%
df.pivot_table(['c3', 'c4'],
               index=['c1'],
               columns=['c2'],
               margins=True,
               aggfunc=sum,
               fill_value=0) #fill_value는 NaN대신 0으로 바꿔준다.
# Out:
#      c3                       c4
# c2    A   B   C  D All         A         B         C         D       All
# c1
# a     6   6   0  0  12  0.780286  0.773745  0.000000  0.000000  1.554031
# b     6   6   6  0  18  0.609423  0.191113  0.490646  0.000000  1.291183
# c     0   0   0  6   6  0.000000  0.000000  0.000000  0.528659  0.528659
# d     0   0   6  0   6  0.000000  0.000000  0.331174  0.000000  0.331174
# All  12  12  12  6  42  1.389709  0.964858  0.821820  0.528659  3.705047

# %%
pd.crosstab(df.c1, df.c2)
# Out:
# c2  A  B  C  D
# c1
# a   1  1  0  0
# b   1  1  1  0
# c   0  0  0  1
# d   0  0  1  0

# %%
pd.crosstab(df.c1, df.c2, values=df.c3, aggfunc=sum, margins=True)
# Out:
# c2      A     B     C    D  All
# c1
# a     6.0   6.0   NaN  NaN   12
# b     6.0   6.0   6.0  NaN   18
# c     NaN   NaN   NaN  6.0    6
# d     NaN   NaN   6.0  NaN    6
# All  12.0  12.0  12.0  6.0   42

# %% [markdown]
# ### 범주형(Categorical) 데이터

# %%
s = pd.Series(['c1', 'c2', 'c1', 'c2', 'c1'] * 2)
s
# Out:
# 0    c1
# 1    c2
# 2    c1
# 3    c2
# 4    c1
# 5    c1
# 6    c2
# 7    c1
# 8    c2
# 9    c1
# dtype: object

# %%
pd.unique(s) #value값이 어떤 것이 있는지 확인
# Out:
# array(['c1', 'c2'], dtype=object)

# %%
pd.value_counts(s) #value값 개수 세기
# Out:
# c1    6
# c2    4
# dtype: int64

# %%
code = pd.Series([0, 1, 0, 1, 0] * 2)
code
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# 5    0
# 6    1
# 7    0
# 8    1
# 9    0
# dtype: int64

# %%
d = pd.Series(['c1', 'c2'])
d
# Out:
# 0    c1
# 1    c2
# dtype: object

# %%
d.take(code) #범주형으로 나타내주는 take
# Out:
# 0    c1
# 1    c2
# 0    c1
# 1    c2
# 0    c1
# 0    c1
# 1    c2
# 0    c1
# 1    c2
# 0    c1
# dtype: object

# %%
df = pd.DataFrame({'id': np.arange(len(s)),
                   'c': s,
                   'v': np.random.randint(1000, 5000, size=len(s))})
df
# Out:
#    id   c     v
# 0   0  c1  4587
# 1   1  c2  4579
# 2   2  c1  1181
# 3   3  c2  4284
# 4   4  c1  2230
# 5   5  c1  3852
# 6   6  c2  4427
# 7   7  c1  3363
# 8   8  c2  3070
# 9   9  c1  4700

# %%
c = df['c'].astype('category') #type: 카테고리
c
# Out:
# 0    c1
# 1    c2
# 2    c1
# 3    c2
# 4    c1
# 5    c1
# 6    c2
# 7    c1
# 8    c2
# 9    c1
# Name: c, dtype: category
# Categories (2, object): ['c1', 'c2']

# %%
c.values
# Out:
# ['c1', 'c2', 'c1', 'c2', 'c1', 'c1', 'c2', 'c1', 'c2', 'c1']
# Categories (2, object): ['c1', 'c2']

# %%
c.values.categories
# Out:
# Index(['c1', 'c2'], dtype='object')

# %%
c.values.codes
# Out:
# array([0, 1, 0, 1, 0, 0, 1, 0, 1, 0], dtype=int8)

# %%
df['c'] = c
df.c
# Out:
# 0    c1
# 1    c2
# 2    c1
# 3    c2
# 4    c1
# 5    c1
# 6    c2
# 7    c1
# 8    c2
# 9    c1
# Name: c, dtype: category
# Categories (2, object): ['c1', 'c2']

# %%
c = pd.Categorical(['c1', 'c2', 'c3', 'c1', 'c2']) #카테고리는 c1, c2, c3 3개
c
# Out:
# ['c1', 'c2', 'c3', 'c1', 'c2']
# Categories (3, object): ['c1', 'c2', 'c3']

# %%
categories = ['c1', 'c2', 'c3']
codes = [0, 1, 2, 0, 1]
c = pd.Categorical.from_codes(codes, categories)
c
# Out:
# ['c1', 'c2', 'c3', 'c1', 'c2']
# Categories (3, object): ['c1', 'c2', 'c3']

# %%
pd.Categorical.from_codes(codes, categories, ordered=True) #ordered는 순서 지정
# Out:
# ['c1', 'c2', 'c3', 'c1', 'c2']
# Categories (3, object): ['c1' < 'c2' < 'c3']

# %%
c.as_ordered() #순서 지정
# Out:
# ['c1', 'c2', 'c3', 'c1', 'c2']
# Categories (3, object): ['c1' < 'c2' < 'c3']

# %%
c.codes
# Out:
# array([0, 1, 2, 0, 1], dtype=int8)

# %%
c.categories
# Out:
# Index(['c1', 'c2', 'c3'], dtype='object')

# %%
c = c.set_categories(['c1','c2', 'c3', 'c4', 'c5'])
c.categories
# Out:
# Index(['c1', 'c2', 'c3', 'c4', 'c5'], dtype='object')

# %%
c.value_counts() #c4와 c5는 사용하지는 않지만 카테고리로 추가되었다.
# Out:
# c1    2
# c2    2
# c3    1
# c4    0
# c5    0
# dtype: int64

# %%
c[c.isin(['c1', 'c3'])]
# Out:
# ['c1', 'c3', 'c1']
# Categories (5, object): ['c1', 'c2', 'c3', 'c4', 'c5']

# %%
c = c.remove_unused_categories() #쓰지 않는 카테고리 제거
c
# Out:
# ['c1', 'c2', 'c3', 'c1', 'c2']
# Categories (3, object): ['c1', 'c2', 'c3']

# %%
c.categories
# Out:
# Index(['c1', 'c2', 'c3'], dtype='object')

# %% [markdown]
# ## 문자열 연산

# %% [markdown]
# #### 문자열 연산자 ("str"로 이용)

# %%
name_tuple = ['Suan Lee', 'Steve Job', 'Larry page', 'Elon Musk', None,
              'Bill Gates', 'Mark Zuckerberg', 'Jeff Bezos']
names = pd.Series(name_tuple)
names
# Out:
# 0           Suan Lee
# 1          Steve Job
# 2         Larry page
# 3          Elon Musk
# 4               None
# 5         Bill Gates
# 6    Mark Zuckerberg
# 7         Jeff Bezos
# dtype: object

# %%
names.str.lower() #문자열이 소문자로 바뀜. 문자열을 접근할 때 str 이용한다는 점 기억
# Out:
# 0           suan lee
# 1          steve job
# 2         larry page
# 3          elon musk
# 4               None
# 5         bill gates
# 6    mark zuckerberg
# 7         jeff bezos
# dtype: object

# %%
names.str.len() #문자열 길이
# Out:
# 0     8.0
# 1     9.0
# 2    10.0
# 3     9.0
# 4     NaN
# 5    10.0
# 6    15.0
# 7    10.0
# dtype: float64

# %%
names.str.split()
# Out:
# 0           [Suan, Lee]
# 1          [Steve, Job]
# 2         [Larry, page]
# 3          [Elon, Musk]
# 4                  None
# 5         [Bill, Gates]
# 6    [Mark, Zuckerberg]
# 7         [Jeff, Bezos]
# dtype: object

# %% [markdown]
# #### 기타 연산자

# %%
names.str[0:4]
# Out:
# 0    Suan
# 1    Stev
# 2    Larr
# 3    Elon
# 4    None
# 5    Bill
# 6    Mark
# 7    Jeff
# dtype: object

# %%
names.str.split().str.get(-1) #뒷부분인 성만 가져옴
# Out:
# 0           Lee
# 1           Job
# 2          page
# 3          Musk
# 4          None
# 5         Gates
# 6    Zuckerberg
# 7         Bezos
# dtype: object

# %%
names.str.repeat(2)
# Out:
# 0                  Suan LeeSuan Lee
# 1                Steve JobSteve Job
# 2              Larry pageLarry page
# 3                Elon MuskElon Musk
# 4                              None
# 5              Bill GatesBill Gates
# 6    Mark ZuckerbergMark Zuckerberg
# 7              Jeff BezosJeff Bezos
# dtype: object

# %%
names.str.join('*') #문자열 간에 * 붙여주기
# Out:
# 0                  S*u*a*n* *L*e*e
# 1                S*t*e*v*e* *J*o*b
# 2              L*a*r*r*y* *p*a*g*e
# 3                E*l*o*n* *M*u*s*k
# 4                             None
# 5              B*i*l*l* *G*a*t*e*s
# 6    M*a*r*k* *Z*u*c*k*e*r*b*e*r*g
# 7              J*e*f*f* *B*e*z*o*s
# dtype: object

# %% [markdown]
# #### 정규표현식

# %%
names.str.match('([A-Za-z]+)') #문자열이 알파벳으로만 구성된것은 True, 아닌 것은 False
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    None
# 5    True
# 6    True
# 7    True
# dtype: object

# %%
names.str.findall('([A-Za-z]+)')
# Out:
# 0           [Suan, Lee]
# 1          [Steve, Job]
# 2         [Larry, page]
# 3          [Elon, Musk]
# 4                  None
# 5         [Bill, Gates]
# 6    [Mark, Zuckerberg]
# 7         [Jeff, Bezos]
# dtype: object

# %% [markdown]
# ## 시계열 처리

# %%
idx = pd.DatetimeIndex(['2019-01-01', '2020-01-01', '2020-02-01', '2020-02-02', '2020-03-01'])
s = pd.Series([0, 1, 2, 3, 4], index=idx)
s
# Out:
# 2019-01-01    0
# 2020-01-01    1
# 2020-02-01    2
# 2020-02-02    3
# 2020-03-01    4
# dtype: int64

# %%
s['2020-01-01':]
# Out:
# 2020-01-01    1
# 2020-02-01    2
# 2020-02-02    3
# 2020-03-01    4
# dtype: int64

# %%
s[:'2020-01-01']
# Out:
# 2019-01-01    0
# 2020-01-01    1
# dtype: int64

# %%
s['2019']
# Out:
# 2019-01-01    0
# dtype: int64

# %% [markdown]
# #### 시계열 데이터 구조

# %%
from datetime import datetime
dates = pd.to_datetime(['12-12-2019', datetime(2020, 1, 1), '2nd of Feb, 2020', '2020-Mar-4', '20200701'])
dates
# Out:
# DatetimeIndex(['2019-12-12', '2020-01-01', '2020-02-02', '2020-03-04',
#                '2020-07-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
dates.to_period('D') #기간을 나타내는 구조로 바뀜
# Out:
# PeriodIndex(['2019-12-12', '2020-01-01', '2020-02-02', '2020-03-04',
#              '2020-07-01'],
#             dtype='period[D]', freq='D')

# %%
dates - dates[0]
# Out:
# TimedeltaIndex(['0 days', '20 days', '52 days', '83 days', '202 days'], dtype='timedelta64[ns]', freq=None)

# %%
pd.date_range('2020-01-01', '2020-07-01')
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-06-22', '2020-06-23', '2020-06-24', '2020-06-25',
#                '2020-06-26', '2020-06-27', '2020-06-28', '2020-06-29',
#                '2020-06-30', '2020-07-01'],
#               dtype='datetime64[ns]', length=183, freq='D')

# %%
pd.date_range('2020-01-01', periods=7)
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2020-01-01', periods=7, freq='M') #매월 말일 출력
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.date_range('2020-01-01', periods=7, freq='H') #1시간 단위 출력
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 01:00:00',
#                '2020-01-01 02:00:00', '2020-01-01 03:00:00',
#                '2020-01-01 04:00:00', '2020-01-01 05:00:00',
#                '2020-01-01 06:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
idx = pd.to_datetime(['2020-01-01 12:00:00', '2020-01-02 00:00:00'] + [None])
idx
# Out:
# DatetimeIndex(['2020-01-01 12:00:00', '2020-01-02 00:00:00', 'NaT'], dtype='datetime64[ns]', freq=None)

# %%
idx[2]
# Out:
# NaT

# %%
pd.isnull(idx) #Null은 True로 출력
# Out:
# array([False, False,  True])

# %% [markdown]
# ### 시계열 기본

# %%
dates = [datetime(2020, 1, 1), datetime(2020, 1, 2), datetime(2020, 1, 4), datetime(2020, 1, 7),
        datetime(2020, 1, 10), datetime(2020, 1, 11), datetime(2020, 1, 15)]
dates
# Out:
# [datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(2020, 1, 2, 0, 0),
#  datetime.datetime(2020, 1, 4, 0, 0),
#  datetime.datetime(2020, 1, 7, 0, 0),
#  datetime.datetime(2020, 1, 10, 0, 0),
#  datetime.datetime(2020, 1, 11, 0, 0),
#  datetime.datetime(2020, 1, 15, 0, 0)]

# %%
ts = pd.Series(np.random.rand(7), index=dates)
ts
# Out:
# 2020-01-01    0.630082
# 2020-01-02    0.562795
# 2020-01-04    0.493072
# 2020-01-07    0.164547
# 2020-01-10    0.741436
# 2020-01-11    0.457271
# 2020-01-15    0.449678
# dtype: float64

# %%
ts.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-04', '2020-01-07',
#                '2020-01-10', '2020-01-11', '2020-01-15'],
#               dtype='datetime64[ns]', freq=None)

# %%
ts.index[0]
# Out:
# Timestamp('2020-01-01 00:00:00')

# %%
ts[ts.index[2]]
# Out:
# 0.49307173986949393

# %%
ts['20200104']
# Out:
# 0.49307173986949393

# %%
ts['1/4/2020']
# Out:
# 0.49307173986949393

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('2017-10-01', periods=1000))
ts
# Out:
# 2017-10-01    0.732156
# 2017-10-02   -1.114415
# 2017-10-03    0.297839
# 2017-10-04   -1.277460
# 2017-10-05    0.229929
#                 ...
# 2020-06-22    0.811235
# 2020-06-23   -0.794675
# 2020-06-24   -0.159927
# 2020-06-25   -2.119479
# 2020-06-26   -0.276210
# Freq: D, Length: 1000, dtype: float64

# %%
ts['2020'] #2020년만 출력
# Out:
# 2020-01-01    0.330672
# 2020-01-02    1.615742
# 2020-01-03   -0.028553
# 2020-01-04    1.691380
# 2020-01-05   -0.475974
#                 ...
# 2020-06-22    0.811235
# 2020-06-23   -0.794675
# 2020-06-24   -0.159927
# 2020-06-25   -2.119479
# 2020-06-26   -0.276210
# Freq: D, Length: 178, dtype: float64

# %%
ts['2020-06'] #2020년 6월 출력
# Out:
# 2020-06-01    1.081358
# 2020-06-02   -1.260013
# 2020-06-03   -1.051967
# 2020-06-04    1.008836
# 2020-06-05   -1.581556
# 2020-06-06   -1.238093
# 2020-06-07   -1.181506
# 2020-06-08   -0.051658
# 2020-06-09   -0.193670
# 2020-06-10    0.638153
# 2020-06-11   -0.707827
# 2020-06-12   -0.494114
# 2020-06-13    0.186066
# 2020-06-14   -0.885407
# 2020-06-15    0.086807
# 2020-06-16    0.336640
# 2020-06-17   -0.184864
# 2020-06-18   -0.160630
# 2020-06-19    0.742282
# 2020-06-20   -1.038140
# 2020-06-21    1.221847
# 2020-06-22    0.811235
# 2020-06-23   -0.794675
# 2020-06-24   -0.159927
# 2020-06-25   -2.119479
# 2020-06-26   -0.276210
# Freq: D, dtype: float64

# %%
ts[datetime(2020,6,20):]
# Out:
# 2020-06-20   -1.038140
# 2020-06-21    1.221847
# 2020-06-22    0.811235
# 2020-06-23   -0.794675
# 2020-06-24   -0.159927
# 2020-06-25   -2.119479
# 2020-06-26   -0.276210
# Freq: D, dtype: float64

# %%
ts['2020-06-10':'2020-06-20']
# Out:
# 2020-06-10    0.638153
# 2020-06-11   -0.707827
# 2020-06-12   -0.494114
# 2020-06-13    0.186066
# 2020-06-14   -0.885407
# 2020-06-15    0.086807
# 2020-06-16    0.336640
# 2020-06-17   -0.184864
# 2020-06-18   -0.160630
# 2020-06-19    0.742282
# 2020-06-20   -1.038140
# Freq: D, dtype: float64

# %%
tdf = pd.DataFrame(np.random.randn(1000, 4),
                   index=pd.date_range('2017-10-01', periods=1000),
                   columns=['A', 'B', 'C', 'D'])
tdf
# Out:
#                    A         B         C         D
# 2017-10-01 -0.725570  1.048176  1.057530  0.484856
# 2017-10-02 -0.215986 -0.805194 -0.272652  0.314532
# 2017-10-03  2.525944 -0.441390 -0.414513  0.709624
# 2017-10-04  0.111338 -2.035483  0.320977  1.242894
# 2017-10-05 -0.125454  1.211555  1.416924 -1.841611
# ...              ...       ...       ...       ...
# 2020-06-22  0.472128 -3.346381  0.164523  1.561702
# 2020-06-23 -1.164366 -0.670870 -0.446890  0.327722
# 2020-06-24 -0.629772  0.279686 -0.985613 -0.934763
# 2020-06-25 -1.555922  0.438413  1.392699 -0.294193
# 2020-06-26 -0.483976  0.486854 -1.253242 -0.650247
#
# [1000 rows x 4 columns]

# %%
tdf['2020']
# Out:
#                    A         B         C         D
# 2020-01-01 -1.863632 -1.246772  0.279455 -0.137881
# 2020-01-02 -0.745866  0.561252 -1.259937 -1.710333
# 2020-01-03  1.000988  0.133262  0.693547  0.869909
# 2020-01-04 -0.836391 -2.597770 -1.331227 -0.433685
# 2020-01-05 -1.925148 -1.888354 -1.775706 -0.237660
# ...              ...       ...       ...       ...
# 2020-06-22  0.472128 -3.346381  0.164523  1.561702
# 2020-06-23 -1.164366 -0.670870 -0.446890  0.327722
# 2020-06-24 -0.629772  0.279686 -0.985613 -0.934763
# 2020-06-25 -1.555922  0.438413  1.392699 -0.294193
# 2020-06-26 -0.483976  0.486854 -1.253242 -0.650247
#
# [178 rows x 4 columns]

# %%
tdf.loc['2020-06']
# Out:
#                    A         B         C         D
# 2020-06-01  0.265898 -0.097969 -0.745855  1.377830
# 2020-06-02  0.593422 -1.223621 -0.912238 -1.233257
# 2020-06-03  1.961087  0.682802  0.210906 -0.098734
# 2020-06-04 -0.001769  1.317090 -0.041063  1.841141
# 2020-06-05  1.505527  0.222404 -0.681434 -1.261669
# 2020-06-06  1.898480  0.191004 -0.512944  1.169872
# 2020-06-07  0.703588  0.325307  1.007860 -0.419103
# 2020-06-08  1.334366  0.209243 -0.161021 -0.039207
# 2020-06-09  0.318232  1.007638  1.579132 -0.116722
# 2020-06-10 -1.261620 -0.478014 -0.374573  0.488237
# 2020-06-11 -2.324913 -0.341484 -0.209564 -1.382799
# 2020-06-12  1.828917 -0.325758 -2.422863  0.118626
# 2020-06-13 -0.226520 -0.094169 -0.552091  2.373536
# 2020-06-14  1.121065 -1.478990 -0.821127  0.637719
# 2020-06-15  2.147812  2.248207  0.799320  0.938791
# 2020-06-16 -0.843263 -0.318435 -0.644263 -0.803683
# 2020-06-17 -1.069871 -2.226242  1.448346 -0.131021
# ...

# %%
tdf['2020-06-20':]
# Out:
#                    A         B         C         D
# 2020-06-20  2.621237  1.457696  1.446009  1.479308
# 2020-06-21 -1.631409  1.707196  0.358692  0.563401
# 2020-06-22  0.472128 -3.346381  0.164523  1.561702
# 2020-06-23 -1.164366 -0.670870 -0.446890  0.327722
# 2020-06-24 -0.629772  0.279686 -0.985613 -0.934763
# 2020-06-25 -1.555922  0.438413  1.392699 -0.294193
# 2020-06-26 -0.483976  0.486854 -1.253242 -0.650247

# %%
tdf['C']
# Out:
# 2017-10-01    1.057530
# 2017-10-02   -0.272652
# 2017-10-03   -0.414513
# 2017-10-04    0.320977
# 2017-10-05    1.416924
#                 ...
# 2020-06-22    0.164523
# 2020-06-23   -0.446890
# 2020-06-24   -0.985613
# 2020-06-25    1.392699
# 2020-06-26   -1.253242
# Freq: D, Name: C, Length: 1000, dtype: float64

# %%
ts = pd.Series(np.random.randn(10),
               index=pd.DatetimeIndex(['2020-01-01', '2020-01-01', '2020-01-02', '2020-01-02',
                                       '2020-01-03', '2020-01-04', '2020-01-05', '2020-01-05',
                                       '2020-01-06', '2020-01-07']))
ts
# Out:
# 2020-01-01   -0.705106
# 2020-01-01   -0.630010
# 2020-01-02   -0.387301
# 2020-01-02    1.697213
# 2020-01-03   -0.323920
# 2020-01-04   -0.205027
# 2020-01-05   -1.138831
# 2020-01-05    0.877544
# 2020-01-06    1.392295
# 2020-01-07   -0.339403
# dtype: float64

# %%
ts.index.is_unique
# Out:
# False

# %%
ts['2020-01-01']
# Out:
# 2020-01-01   -0.705106
# 2020-01-01   -0.630010
# dtype: float64

# %%
ts.groupby(level=0).mean()
# Out:
# 2020-01-01   -0.667558
# 2020-01-02    0.654956
# 2020-01-03   -0.323920
# 2020-01-04   -0.205027
# 2020-01-05   -0.130643
# 2020-01-06    1.392295
# 2020-01-07   -0.339403
# dtype: float64

# %%
pd.date_range('2020-01-01', '2020-07-01')
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-06-22', '2020-06-23', '2020-06-24', '2020-06-25',
#                '2020-06-26', '2020-06-27', '2020-06-28', '2020-06-29',
#                '2020-06-30', '2020-07-01'],
#               dtype='datetime64[ns]', length=183, freq='D')

# %%
pd.date_range(start='2020-01-01', periods=10)
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(end='2020-07-01', periods=10)
# Out:
# DatetimeIndex(['2020-06-22', '2020-06-23', '2020-06-24', '2020-06-25',
#                '2020-06-26', '2020-06-27', '2020-06-28', '2020-06-29',
#                '2020-06-30', '2020-07-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2020-07-01', '2020-07-07', freq='B') #B는 Businessday로 주말제외 영업일 의미
# Out:
# DatetimeIndex(['2020-07-01', '2020-07-02', '2020-07-03', '2020-07-06',
#                '2020-07-07'],
#               dtype='datetime64[ns]', freq='B')

# %% [markdown]
# ### 주기와 오프셋

# %%
pd.timedelta_range(0, periods=12, freq='H') #시간단위
# Out:
# TimedeltaIndex(['0 days 00:00:00', '0 days 01:00:00', '0 days 02:00:00',
#                 '0 days 03:00:00', '0 days 04:00:00', '0 days 05:00:00',
#                 '0 days 06:00:00', '0 days 07:00:00', '0 days 08:00:00',
#                 '0 days 09:00:00', '0 days 10:00:00', '0 days 11:00:00'],
#                dtype='timedelta64[ns]', freq='H')

# %%
pd.timedelta_range(0, periods=60, freq='T') #분단위
# Out:
# TimedeltaIndex(['0 days 00:00:00', '0 days 00:01:00', '0 days 00:02:00',
#                 '0 days 00:03:00', '0 days 00:04:00', '0 days 00:05:00',
#                 '0 days 00:06:00', '0 days 00:07:00', '0 days 00:08:00',
#                 '0 days 00:09:00', '0 days 00:10:00', '0 days 00:11:00',
#                 '0 days 00:12:00', '0 days 00:13:00', '0 days 00:14:00',
#                 '0 days 00:15:00', '0 days 00:16:00', '0 days 00:17:00',
#                 '0 days 00:18:00', '0 days 00:19:00', '0 days 00:20:00',
#                 '0 days 00:21:00', '0 days 00:22:00', '0 days 00:23:00',
#                 '0 days 00:24:00', '0 days 00:25:00', '0 days 00:26:00',
#                 '0 days 00:27:00', '0 days 00:28:00', '0 days 00:29:00',
#                 '0 days 00:30:00', '0 days 00:31:00', '0 days 00:32:00',
#                 '0 days 00:33:00', '0 days 00:34:00', '0 days 00:35:00',
#                 '0 days 00:36:00', '0 days 00:37:00', '0 days 00:38:00',
# ...

# %%
pd.timedelta_range(0, periods=10, freq='1H30T') #1시간30분 주기
# Out:
# TimedeltaIndex(['0 days 00:00:00', '0 days 01:30:00', '0 days 03:00:00',
#                 '0 days 04:30:00', '0 days 06:00:00', '0 days 07:30:00',
#                 '0 days 09:00:00', '0 days 10:30:00', '0 days 12:00:00',
#                 '0 days 13:30:00'],
#                dtype='timedelta64[ns]', freq='90T')

# %%
pd.date_range('2020-01-01', periods=20, freq='B')
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-06',
#                '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-20', '2020-01-21', '2020-01-22',
#                '2020-01-23', '2020-01-24', '2020-01-27', '2020-01-28'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range('2020-01-01', periods=30, freq='2H')
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 02:00:00',
#                '2020-01-01 04:00:00', '2020-01-01 06:00:00',
#                '2020-01-01 08:00:00', '2020-01-01 10:00:00',
#                '2020-01-01 12:00:00', '2020-01-01 14:00:00',
#                '2020-01-01 16:00:00', '2020-01-01 18:00:00',
#                '2020-01-01 20:00:00', '2020-01-01 22:00:00',
#                '2020-01-02 00:00:00', '2020-01-02 02:00:00',
#                '2020-01-02 04:00:00', '2020-01-02 06:00:00',
#                '2020-01-02 08:00:00', '2020-01-02 10:00:00',
#                '2020-01-02 12:00:00', '2020-01-02 14:00:00',
#                '2020-01-02 16:00:00', '2020-01-02 18:00:00',
#                '2020-01-02 20:00:00', '2020-01-02 22:00:00',
#                '2020-01-03 00:00:00', '2020-01-03 02:00:00',
#                '2020-01-03 04:00:00', '2020-01-03 06:00:00',
#                '2020-01-03 08:00:00', '2020-01-03 10:00:00'],
#               dtype='datetime64[ns]', freq='2H')

# %%
pd.date_range('2020-01-01', periods=20, freq='s')
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 00:00:01',
#                '2020-01-01 00:00:02', '2020-01-01 00:00:03',
#                '2020-01-01 00:00:04', '2020-01-01 00:00:05',
#                '2020-01-01 00:00:06', '2020-01-01 00:00:07',
#                '2020-01-01 00:00:08', '2020-01-01 00:00:09',
#                '2020-01-01 00:00:10', '2020-01-01 00:00:11',
#                '2020-01-01 00:00:12', '2020-01-01 00:00:13',
#                '2020-01-01 00:00:14', '2020-01-01 00:00:15',
#                '2020-01-01 00:00:16', '2020-01-01 00:00:17',
#                '2020-01-01 00:00:18', '2020-01-01 00:00:19'],
#               dtype='datetime64[ns]', freq='S')

# %% [markdown]
# ### 시프트(Shift)

# %%
ts = pd.Series(np.random.randn(5),
               index=pd.date_range('2020-01-01', periods=5, freq='B'))
ts
# Out:
# 2020-01-01    0.345391
# 2020-01-02    0.594138
# 2020-01-03    0.185973
# 2020-01-06   -1.252716
# 2020-01-07    1.474798
# Freq: B, dtype: float64

# %%
ts.shift(1) #값이 1칸씩 아래로 밀림
# Out:
# 2020-01-01         NaN
# 2020-01-02    0.345391
# 2020-01-03    0.594138
# 2020-01-06    0.185973
# 2020-01-07   -1.252716
# Freq: B, dtype: float64

# %%
ts.shift(3) #값이 3칸씩 아래로 밀림
# Out:
# 2020-01-01         NaN
# 2020-01-02         NaN
# 2020-01-03         NaN
# 2020-01-06    0.345391
# 2020-01-07    0.594138
# Freq: B, dtype: float64

# %%
ts.shift(-2) #값이 2칸씩 위로 밀림
# Out:
# 2020-01-01    0.185973
# 2020-01-02   -1.252716
# 2020-01-03    1.474798
# 2020-01-06         NaN
# 2020-01-07         NaN
# Freq: B, dtype: float64

# %%
ts.shift(3, freq='B')
# Out:
# 2020-01-06    0.345391
# 2020-01-07    0.594138
# 2020-01-08    0.185973
# 2020-01-09   -1.252716
# 2020-01-10    1.474798
# Freq: B, dtype: float64

# %%
ts.shift(2, freq='W')
# Out:
# 2020-01-12    0.345391
# 2020-01-12    0.594138
# 2020-01-12    0.185973
# 2020-01-19   -1.252716
# 2020-01-19    1.474798
# dtype: float64

# %% [markdown]
# ### 시간대 처리
#
# * 국제표준시(Coordinated Universal Time, UTC)를 기준으로 떨어진 거리만큼 오프셋으로 시간대 처리
# * 전 세계의 시간대 정보를 모아놓은 올슨 데이터베이스를 활용한 라이브러리인 `pytz` 사용

# %%
import pytz
pytz.common_timezones
# Out:
# ['Africa/Abidjan', 'Africa/Accra', 'Africa/Addis_Ababa', 'Africa/Algiers', 'Africa/Asmara', 'Africa/Bamako', 'Africa/Bangui', 'Africa/Banjul', 'Africa/Bissau', 'Africa/Blantyre', 'Africa/Brazzaville', 'Africa/Bujumbura', 'Africa/Cairo', 'Africa/Casablanca', 'Africa/Ceuta', 'Africa/Conakry', 'Africa/Dakar', 'Africa/Dar_es_Salaam', 'Africa/Djibouti', 'Africa/Douala', 'Africa/El_Aaiun', 'Africa/Freetown', 'Africa/Gaborone', 'Africa/Harare', 'Africa/Johannesburg', 'Africa/Juba', 'Africa/Kampala', 'Africa/Khartoum', 'Africa/Kigali', 'Africa/Kinshasa', 'Africa/Lagos', 'Africa/Libreville', 'Africa/Lome', 'Africa/Luanda', 'Africa/Lubumbashi', 'Africa/Lusaka', 'Africa/Malabo', 'Africa/Maputo', 'Africa/Maseru', 'Africa/Mbabane', 'Africa/Mogadishu', 'Africa/Monrovia', 'Africa/Nairobi', 'Africa/Ndjamena', 'Africa/Niamey', 'Africa/Nouakchott', 'Africa/Ouagadougou', 'Africa/Porto-Novo', 'Africa/Sao_Tome', 'Africa/Tripoli', 'Africa/Tunis', 'Africa/Windhoek', 'America/Adak', 'America/Anchorage', 'Am
# ...

# %%
tz = pytz.timezone('Asia/Seoul')
tz
# Out:
# <DstTzInfo 'Asia/Seoul' LMT+8:28:00 STD>

# %%
dinx = pd.date_range('2020-01-01 09:00', periods=7, freq='B')
ts = pd.Series(np.random.randn(len(dinx)), index=dinx)
ts
# Out:
# 2020-01-01 09:00:00   -0.425799
# 2020-01-02 09:00:00    0.706803
# 2020-01-03 09:00:00    1.131420
# 2020-01-06 09:00:00   -0.567147
# 2020-01-07 09:00:00    0.558999
# 2020-01-08 09:00:00    0.276603
# 2020-01-09 09:00:00    0.034991
# Freq: B, dtype: float64

# %%
pd.date_range('2020-01-01 09:00', periods=7, freq='B', tz='UTC')
# Out:
# DatetimeIndex(['2020-01-01 09:00:00+00:00', '2020-01-02 09:00:00+00:00',
#                '2020-01-03 09:00:00+00:00', '2020-01-06 09:00:00+00:00',
#                '2020-01-07 09:00:00+00:00', '2020-01-08 09:00:00+00:00',
#                '2020-01-09 09:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='B')

# %%
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2020-01-01 09:00:00+00:00   -0.425799
# 2020-01-02 09:00:00+00:00    0.706803
# 2020-01-03 09:00:00+00:00    1.131420
# 2020-01-06 09:00:00+00:00   -0.567147
# 2020-01-07 09:00:00+00:00    0.558999
# 2020-01-08 09:00:00+00:00    0.276603
# 2020-01-09 09:00:00+00:00    0.034991
# Freq: B, dtype: float64

# %%
ts_utc.index
# Out:
# DatetimeIndex(['2020-01-01 09:00:00+00:00', '2020-01-02 09:00:00+00:00',
#                '2020-01-03 09:00:00+00:00', '2020-01-06 09:00:00+00:00',
#                '2020-01-07 09:00:00+00:00', '2020-01-08 09:00:00+00:00',
#                '2020-01-09 09:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='B')

# %%
ts_utc.tz_convert('Asia/Seoul') #UTC+9로 시간 바껴짐
# Out:
# 2020-01-01 18:00:00+09:00   -0.425799
# 2020-01-02 18:00:00+09:00    0.706803
# 2020-01-03 18:00:00+09:00    1.131420
# 2020-01-06 18:00:00+09:00   -0.567147
# 2020-01-07 18:00:00+09:00    0.558999
# 2020-01-08 18:00:00+09:00    0.276603
# 2020-01-09 18:00:00+09:00    0.034991
# Freq: B, dtype: float64

# %%
ts_seoul = ts.tz_localize('Asia/Seoul')
ts_seoul
# Out:
# 2020-01-01 09:00:00+09:00   -0.425799
# 2020-01-02 09:00:00+09:00    0.706803
# 2020-01-03 09:00:00+09:00    1.131420
# 2020-01-06 09:00:00+09:00   -0.567147
# 2020-01-07 09:00:00+09:00    0.558999
# 2020-01-08 09:00:00+09:00    0.276603
# 2020-01-09 09:00:00+09:00    0.034991
# dtype: float64

# %%
ts_seoul.tz_convert('UTC')
# Out:
# 2020-01-01 00:00:00+00:00   -0.425799
# 2020-01-02 00:00:00+00:00    0.706803
# 2020-01-03 00:00:00+00:00    1.131420
# 2020-01-06 00:00:00+00:00   -0.567147
# 2020-01-07 00:00:00+00:00    0.558999
# 2020-01-08 00:00:00+00:00    0.276603
# 2020-01-09 00:00:00+00:00    0.034991
# dtype: float64

# %%
ts_seoul.tz_convert('Europe/Berlin')
# Out:
# 2020-01-01 01:00:00+01:00   -0.425799
# 2020-01-02 01:00:00+01:00    0.706803
# 2020-01-03 01:00:00+01:00    1.131420
# 2020-01-06 01:00:00+01:00   -0.567147
# 2020-01-07 01:00:00+01:00    0.558999
# 2020-01-08 01:00:00+01:00    0.276603
# 2020-01-09 01:00:00+01:00    0.034991
# dtype: float64

# %%
ts.index.tz_localize('America/New_York')
# Out:
# DatetimeIndex(['2020-01-01 09:00:00-05:00', '2020-01-02 09:00:00-05:00',
#                '2020-01-03 09:00:00-05:00', '2020-01-06 09:00:00-05:00',
#                '2020-01-07 09:00:00-05:00', '2020-01-08 09:00:00-05:00',
#                '2020-01-09 09:00:00-05:00'],
#               dtype='datetime64[ns, America/New_York]', freq=None)

# %%
stamp = pd.Timestamp('2020-01-01 12:00')
stamp_utc = stamp.tz_localize('UTC') #UTC를 기준으로
stamp_utc
# Out:
# Timestamp('2020-01-01 12:00:00+0000', tz='UTC')

# %%
stamp_utc.value
# Out:
# 1577880000000000000

# %%
stamp_utc.tz_convert('Asia/Seoul') #UTC 서울 시간대로 바꾸기
# Out:
# Timestamp('2020-01-01 21:00:00+0900', tz='Asia/Seoul')

# %%
stamp_utc.tz_convert('Asia/Seoul').value
# Out:
# 1577880000000000000

# %%
stamp_New_York = pd.Timestamp('2020-01-01 12:00', tz='America/New_York')
stamp_New_York
# Out:
# Timestamp('2020-01-01 12:00:00-0500', tz='America/New_York')

# %%
stamp_New_York.value
# Out:
# 1577898000000000000

# %%
stamp_utc.tz_convert('Asia/Shanghai')
# Out:
# Timestamp('2020-01-01 20:00:00+0800', tz='Asia/Shanghai')

# %%
stamp = pd.Timestamp('2020-01-01 12:00', tz='Asia/Seoul')
stamp
# Out:
# Timestamp('2020-01-01 12:00:00+0900', tz='Asia/Seoul')

# %%
from pandas.tseries.offsets import Hour
stamp + Hour()
# Out:
# Timestamp('2020-01-01 13:00:00+0900', tz='Asia/Seoul')

# %%
stamp + 3 * Hour()
# Out:
# Timestamp('2020-01-01 15:00:00+0900', tz='Asia/Seoul')

# %%
ts_utc
# Out:
# 2020-01-01 09:00:00+00:00   -0.425799
# 2020-01-02 09:00:00+00:00    0.706803
# 2020-01-03 09:00:00+00:00    1.131420
# 2020-01-06 09:00:00+00:00   -0.567147
# 2020-01-07 09:00:00+00:00    0.558999
# 2020-01-08 09:00:00+00:00    0.276603
# 2020-01-09 09:00:00+00:00    0.034991
# Freq: B, dtype: float64

# %%
ts1 = ts_utc[:5].tz_convert('Europe/Berlin')
ts2 = ts_utc[2:].tz_convert('America/New_York')
ts = ts1 + ts2
ts
# Out:
# 2020-01-01 09:00:00+00:00         NaN
# 2020-01-02 09:00:00+00:00         NaN
# 2020-01-03 09:00:00+00:00    2.262841
# 2020-01-06 09:00:00+00:00   -1.134293
# 2020-01-07 09:00:00+00:00    1.117999
# 2020-01-08 09:00:00+00:00         NaN
# 2020-01-09 09:00:00+00:00         NaN
# Freq: B, dtype: float64

# %%
ts.index
# Out:
# DatetimeIndex(['2020-01-01 09:00:00+00:00', '2020-01-02 09:00:00+00:00',
#                '2020-01-03 09:00:00+00:00', '2020-01-06 09:00:00+00:00',
#                '2020-01-07 09:00:00+00:00', '2020-01-08 09:00:00+00:00',
#                '2020-01-09 09:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='B')

# %% [markdown]
# ### 기간과 기간 연산

# %%
p = pd.Period(2020, freq='A-JAN')
p
# Out:
# Period('2020', 'A-JAN')

# %%
p + 2
# Out:
# Period('2022', 'A-JAN')

# %%
p - 3
# Out:
# Period('2017', 'A-JAN')

# %%
p1 = pd.Period(2010,freq='A-JAN')
p2 = pd.Period(2020,freq='A-JAN')
p2 - p1
# Out:
# <10 * YearEnds: month=1>

# %%
pr = pd.period_range('2020-01-01', '2020-06-30', freq='M')

# %%
pd.Series(np.random.randn(6), index=pr)
# Out:
# 2020-01   -0.461457
# 2020-02    0.877610
# 2020-03   -0.860562
# 2020-04   -0.012614
# 2020-05    1.758273
# 2020-06   -0.295162
# Freq: M, dtype: float64

# %%
pidx = pd.PeriodIndex(['2020-1','2020-2','2020-4'], freq='M')
pidx
# Out:
# PeriodIndex(['2020-01', '2020-02', '2020-04'], dtype='period[M]', freq='M')

# %%
p = pd.Period('2020', freq='A-FEB')
p
# Out:
# Period('2020', 'A-FEB')

# %%
p.asfreq('M', how='start')
# Out:
# Period('2019-03', 'M')

# %%
p.asfreq('M', how='end')
# Out:
# Period('2020-02', 'M')

# %%
p = pd.Period('2020', freq='A-OCT')
p
# Out:
# Period('2020', 'A-OCT')

# %%
p.asfreq('M', how='start')
# Out:
# Period('2019-11', 'M')

# %%
p.asfreq('M', how='end')
# Out:
# Period('2020-10', 'M')

# %%
pr = pd.period_range('2010', '2020', freq='A-JAN')
ts = pd.Series(np.random.randn(len(pr)), index=pr)
ts
# Out:
# 2010   -0.188836
# 2011    0.874062
# 2012   -0.202640
# 2013    1.007871
# 2014   -0.806255
# 2015   -1.426999
# 2016    0.541345
# 2017    0.967575
# 2018   -0.846339
# 2019    0.762782
# 2020    0.208757
# Freq: A-JAN, dtype: float64

# %%
ts.asfreq('M', how='start')
# Out:
# 2009-02   -0.188836
# 2010-02    0.874062
# 2011-02   -0.202640
# 2012-02    1.007871
# 2013-02   -0.806255
# 2014-02   -1.426999
# 2015-02    0.541345
# 2016-02    0.967575
# 2017-02   -0.846339
# 2018-02    0.762782
# 2019-02    0.208757
# Freq: M, dtype: float64

# %%
ts.asfreq('M', how='end')
# Out:
# 2010-01   -0.188836
# 2011-01    0.874062
# 2012-01   -0.202640
# 2013-01    1.007871
# 2014-01   -0.806255
# 2015-01   -1.426999
# 2016-01    0.541345
# 2017-01    0.967575
# 2018-01   -0.846339
# 2019-01    0.762782
# 2020-01    0.208757
# Freq: M, dtype: float64

# %%
ts.asfreq('B', how='end')
# Out:
# 2010-01-29   -0.188836
# 2011-01-31    0.874062
# 2012-01-31   -0.202640
# 2013-01-31    1.007871
# 2014-01-31   -0.806255
# 2015-01-30   -1.426999
# 2016-01-29    0.541345
# 2017-01-31    0.967575
# 2018-01-31   -0.846339
# 2019-01-31    0.762782
# 2020-01-31    0.208757
# Freq: B, dtype: float64

# %%
p = pd.Period('2020Q2', freq='Q-FEB')
p
# Out:
# Period('2020Q2', 'Q-FEB')

# %%
p.asfreq('D', how='start')
# Out:
# Period('2019-06-01', 'D')

# %%
p.asfreq('D', how='end')
# Out:
# Period('2019-08-31', 'D')

# %%
pr = pd.period_range('2019Q3', '2020Q3', freq='Q-JAN')
ts = pd.Series(np.arange(len(pr)), index=pr)
ts
# Out:
# 2019Q3    0
# 2019Q4    1
# 2020Q1    2
# 2020Q2    3
# 2020Q3    4
# Freq: Q-JAN, dtype: int32

# %%
pr = pd.date_range('2020-01-01', periods=5, freq='Q-JAN')
ts = pd.Series(np.arange(5), index=pr)
ts
# Out:
# 2020-01-31    0
# 2020-04-30    1
# 2020-07-31    2
# 2020-10-31    3
# 2021-01-31    4
# Freq: Q-JAN, dtype: int32

# %%
ts.to_period()
# Out:
# 2020Q4    0
# 2021Q1    1
# 2021Q2    2
# 2021Q3    3
# 2021Q4    4
# Freq: Q-JAN, dtype: int32

# %%
pr = pd.date_range('2020-01-01', periods=5, freq='D')
ts = pd.Series(np.random.randn(len(pr)), index=pr)
ts
# Out:
# 2020-01-01   -1.723554
# 2020-01-02    0.096771
# 2020-01-03   -1.292324
# 2020-01-04   -1.206766
# 2020-01-05    2.320995
# Freq: D, dtype: float64

# %%
p = ts.to_period('M')
p
# Out:
# 2020-01   -1.723554
# 2020-01    0.096771
# 2020-01   -1.292324
# 2020-01   -1.206766
# 2020-01    2.320995
# Freq: M, dtype: float64

# %%
p.to_timestamp(how='start')
# Out:
# 2020-01-01   -1.723554
# 2020-01-01    0.096771
# 2020-01-01   -1.292324
# 2020-01-01   -1.206766
# 2020-01-01    2.320995
# dtype: float64

# %%
p.to_timestamp(how='end')
# Out:
# 2020-01-31 23:59:59.999999999   -1.723554
# 2020-01-31 23:59:59.999999999    0.096771
# 2020-01-31 23:59:59.999999999   -1.292324
# 2020-01-31 23:59:59.999999999   -1.206766
# 2020-01-31 23:59:59.999999999    2.320995
# dtype: float64

# %% [markdown]
# ### 리샘플링(Resampling)
#
# * 리샘플링(Resampling): 시계열의 빈도 변환
# * 다운샘플링(Down sampling): 상위 빈도 데이터를 하위 빈도 데이터로 집계
# * 업샘플링(Up sampling): 하위 빈도 데이터를 상위 빈도 데이터로 집계

# %%
dr = pd.date_range('2020-01-01', periods=200, freq='D')
ts = pd.Series(np.random.randn(len(dr)), index=dr)
ts
# Out:
# 2020-01-01   -0.941444
# 2020-01-02    0.267703
# 2020-01-03    0.490109
# 2020-01-04   -1.495641
# 2020-01-05    0.569392
#                 ...
# 2020-07-14    0.964792
# 2020-07-15    1.094050
# 2020-07-16    1.444504
# 2020-07-17   -2.055763
# 2020-07-18   -0.948487
# Freq: D, Length: 200, dtype: float64

# %%
ts.resample('M').mean() #기존의 일을 해당 월의 마지막 일로 묶고 평균으로 value값 표시, 업샘플링에 해당
# Out:
# 2020-01-31    0.065349
# 2020-02-29    0.126044
# 2020-03-31    0.064100
# 2020-04-30    0.250744
# 2020-05-31    0.126859
# 2020-06-30    0.002473
# 2020-07-31    0.117071
# Freq: M, dtype: float64

# %%
ts.resample('M', kind='period').mean() #월 주기로 평균값 계산
# Out:
# 2020-01    0.065349
# 2020-02    0.126044
# 2020-03    0.064100
# 2020-04    0.250744
# 2020-05    0.126859
# 2020-06    0.002473
# 2020-07    0.117071
# Freq: M, dtype: float64

# %%
dr = pd.date_range('2020-01-01', periods=10, freq='T')
ts = pd.Series(np.arange(10), index=dr)
ts
# Out:
# 2020-01-01 00:00:00    0
# 2020-01-01 00:01:00    1
# 2020-01-01 00:02:00    2
# 2020-01-01 00:03:00    3
# 2020-01-01 00:04:00    4
# 2020-01-01 00:05:00    5
# 2020-01-01 00:06:00    6
# 2020-01-01 00:07:00    7
# 2020-01-01 00:08:00    8
# 2020-01-01 00:09:00    9
# Freq: T, dtype: int32

# %%
ts.resample('2T', closed='left').sum()
# Out:
# 2020-01-01 00:00:00     1
# 2020-01-01 00:02:00     5
# 2020-01-01 00:04:00     9
# 2020-01-01 00:06:00    13
# 2020-01-01 00:08:00    17
# Freq: 2T, dtype: int32

# %%
ts.resample('2T', closed='right').sum()
# Out:
# 2019-12-31 23:58:00     0
# 2020-01-01 00:00:00     3
# 2020-01-01 00:02:00     7
# 2020-01-01 00:04:00    11
# 2020-01-01 00:06:00    15
# 2020-01-01 00:08:00     9
# Freq: 2T, dtype: int32

# %%
ts.resample('2T', closed='right', label='right').sum()
# Out:
# 2020-01-01 00:00:00     0
# 2020-01-01 00:02:00     3
# 2020-01-01 00:04:00     7
# 2020-01-01 00:06:00    11
# 2020-01-01 00:08:00    15
# 2020-01-01 00:10:00     9
# Freq: 2T, dtype: int32

# %%
ts.resample('2T', closed='right', label='right', loffset='-1s').sum() #loffset은 -1초씩 조정
# Out:
# <ipython-input-484-f09f275c4eda>:1: FutureWarning: 'loffset' in .resample() and in Grouper() is deprecated.
#
# >>> df.resample(freq="3s", loffset="8H")
#
# becomes:
#
# >>> from pandas.tseries.frequencies import to_offset
# >>> df = df.resample(freq="3s").mean()
# >>> df.index = df.index.to_timestamp() + to_offset("8H")
#
#   ts.resample('2T', closed='right', label='right', loffset='-1s').sum()
# 2019-12-31 23:59:59     0
# 2020-01-01 00:01:59     3
# 2020-01-01 00:03:59     7
# 2020-01-01 00:05:59    11
# 2020-01-01 00:07:59    15
# 2020-01-01 00:09:59     9
# Freq: 2T, dtype: int32

# %%
ts.resample('2T').ohlc() #open은 시가, high은 고가, low는 저가, close는 종가
# Out:
#                      open  high  low  close
# 2020-01-01 00:00:00     0     1    0      1
# 2020-01-01 00:02:00     2     3    2      3
# 2020-01-01 00:04:00     4     5    4      5
# 2020-01-01 00:06:00     6     7    6      7
# 2020-01-01 00:08:00     8     9    8      9

# %%
df = pd.DataFrame(np.random.randn(10, 4),
                  index=pd.date_range('2019-10-01', periods=10, freq='M'),
                  columns=['c1', 'c2', 'c3', 'c4'])
df
# Out:
#                   c1        c2        c3        c4
# 2019-10-31  1.124527  0.304131  0.978281 -0.717205
# 2019-11-30  1.164181  0.008120  0.307739  1.089408
# 2019-12-31  0.049855  0.795171 -2.494668  1.619439
# 2020-01-31  0.919365  1.074000  1.283824 -0.286353
# 2020-02-29  2.027175 -0.326265 -0.136187  0.199793
# 2020-03-31 -0.253942  0.126218  0.313009 -0.223168
# 2020-04-30 -0.260708 -0.472264  0.882920  0.978039
# 2020-05-31  0.436032  0.731978  0.091098  1.368110
# 2020-06-30 -0.717550  1.079103  0.615917 -0.123561
# 2020-07-31  0.116678  0.183118  0.129925 -0.849532

# %%
df.resample('Y').asfreq()
# Out:
#                   c1        c2        c3        c4
# 2019-12-31  0.049855  0.795171 -2.494668  1.619439
# 2020-12-31       NaN       NaN       NaN       NaN

# %%
df.resample('W-FRI').asfreq() #금요일을 주기로
# Out:
#                   c1        c2        c3        c4
# 2019-11-01       NaN       NaN       NaN       NaN
# 2019-11-08       NaN       NaN       NaN       NaN
# 2019-11-15       NaN       NaN       NaN       NaN
# 2019-11-22       NaN       NaN       NaN       NaN
# 2019-11-29       NaN       NaN       NaN       NaN
# 2019-12-06       NaN       NaN       NaN       NaN
# 2019-12-13       NaN       NaN       NaN       NaN
# 2019-12-20       NaN       NaN       NaN       NaN
# 2019-12-27       NaN       NaN       NaN       NaN
# 2020-01-03       NaN       NaN       NaN       NaN
# 2020-01-10       NaN       NaN       NaN       NaN
# 2020-01-17       NaN       NaN       NaN       NaN
# 2020-01-24       NaN       NaN       NaN       NaN
# 2020-01-31  0.919365  1.074000  1.283824 -0.286353
# 2020-02-07       NaN       NaN       NaN       NaN
# 2020-02-14       NaN       NaN       NaN       NaN
# 2020-02-21       NaN       NaN       NaN       NaN
# ...

# %%
df.resample('H').asfreq()
# Out:
#                            c1        c2        c3        c4
# 2019-10-31 00:00:00  1.124527  0.304131  0.978281 -0.717205
# 2019-10-31 01:00:00       NaN       NaN       NaN       NaN
# 2019-10-31 02:00:00       NaN       NaN       NaN       NaN
# 2019-10-31 03:00:00       NaN       NaN       NaN       NaN
# 2019-10-31 04:00:00       NaN       NaN       NaN       NaN
# ...                       ...       ...       ...       ...
# 2020-07-30 20:00:00       NaN       NaN       NaN       NaN
# 2020-07-30 21:00:00       NaN       NaN       NaN       NaN
# 2020-07-30 22:00:00       NaN       NaN       NaN       NaN
# 2020-07-30 23:00:00       NaN       NaN       NaN       NaN
# 2020-07-31 00:00:00  0.116678  0.183118  0.129925 -0.849532
#
# [6577 rows x 4 columns]

# %%
df.resample('H').ffill() #forward(이전)값으로 값채우기
# Out:
#                            c1        c2        c3        c4
# 2019-10-31 00:00:00  1.124527  0.304131  0.978281 -0.717205
# 2019-10-31 01:00:00  1.124527  0.304131  0.978281 -0.717205
# 2019-10-31 02:00:00  1.124527  0.304131  0.978281 -0.717205
# 2019-10-31 03:00:00  1.124527  0.304131  0.978281 -0.717205
# 2019-10-31 04:00:00  1.124527  0.304131  0.978281 -0.717205
# ...                       ...       ...       ...       ...
# 2020-07-30 20:00:00 -0.717550  1.079103  0.615917 -0.123561
# 2020-07-30 21:00:00 -0.717550  1.079103  0.615917 -0.123561
# 2020-07-30 22:00:00 -0.717550  1.079103  0.615917 -0.123561
# 2020-07-30 23:00:00 -0.717550  1.079103  0.615917 -0.123561
# 2020-07-31 00:00:00  0.116678  0.183118  0.129925 -0.849532
#
# [6577 rows x 4 columns]

# %%
df.resample('H').ffill(limit=2) #2개만 채우기
# Out:
#                            c1        c2        c3        c4
# 2019-10-31 00:00:00  1.124527  0.304131  0.978281 -0.717205
# 2019-10-31 01:00:00  1.124527  0.304131  0.978281 -0.717205
# 2019-10-31 02:00:00  1.124527  0.304131  0.978281 -0.717205
# 2019-10-31 03:00:00       NaN       NaN       NaN       NaN
# 2019-10-31 04:00:00       NaN       NaN       NaN       NaN
# ...                       ...       ...       ...       ...
# 2020-07-30 20:00:00       NaN       NaN       NaN       NaN
# 2020-07-30 21:00:00       NaN       NaN       NaN       NaN
# 2020-07-30 22:00:00       NaN       NaN       NaN       NaN
# 2020-07-30 23:00:00       NaN       NaN       NaN       NaN
# 2020-07-31 00:00:00  0.116678  0.183118  0.129925 -0.849532
#
# [6577 rows x 4 columns]

# %%
df.resample('Q-DEC').mean()
# Out:
#                   c1        c2        c3        c4
# 2019-12-31  0.779521  0.369140 -0.402883  0.663881
# 2020-03-31  0.897533  0.291317  0.486882 -0.103243
# 2020-06-30 -0.180742  0.446273  0.529978  0.740863
# 2020-09-30  0.116678  0.183118  0.129925 -0.849532

# %%
df.resample('Y').mean()
# Out:
#                   c1       c2        c3        c4
# 2019-12-31  0.779521  0.36914 -0.402883  0.663881
# 2020-12-31  0.323864  0.34227  0.454358  0.151904

# %% [markdown]
# ### 무빙 윈도우(Moving Window) `중요`

# %%
df = pd.DataFrame(np.random.randn(300, 4), 
                  index=pd.date_range('2020-01-01', periods=300, freq='D'),
                  columns=['c1', 'c2', 'c3', 'c4'])
df
# Out:
#                   c1        c2        c3        c4
# 2020-01-01 -0.057462  0.201361  0.689595  1.233531
# 2020-01-02  1.055585  0.788359 -0.999234  0.190735
# 2020-01-03 -0.394629  0.358199  1.213216 -1.369659
# 2020-01-04  1.388724 -0.989325 -0.261218  0.785103
# 2020-01-05 -0.583798 -0.540135 -0.740174 -1.048050
# ...              ...       ...       ...       ...
# 2020-10-22 -0.045469  2.548876  0.763735  0.823356
# 2020-10-23 -1.325791  0.824208  1.291912 -1.227151
# 2020-10-24  1.520507 -0.871901 -0.311016 -0.878392
# 2020-10-25  1.275086 -0.238735  0.923284  0.281132
# 2020-10-26 -1.079616  0.084939 -0.046333 -0.956050
#
# [300 rows x 4 columns]

# %%
df.rolling(30).mean().plot() #30일 이동평균 그래프
# Out:
# <AxesSubplot:>

# %%
df.rolling(60).mean().plot() #60일 이동평균 그래프
# Out:
# <AxesSubplot:>

# %%
df.c1.rolling(60, min_periods=10).std().plot() #최소간격치 10일로 c1의 60일 이동표본편차 그래프
# Out:
# <AxesSubplot:>

# %%
df.c1.rolling(60, min_periods=10).std()[10:50].plot() #일부분만 보기
# Out:
# <AxesSubplot:>

# %%
df.rolling(60, min_periods=10).std()[10:50].plot()
# Out:
# <AxesSubplot:>

# %%
df.rolling(60, min_periods=10).std().expanding().mean().plot()
# Out:
# <AxesSubplot:>

# %%
df.rolling(60).mean().plot(logy=True) #y축 log로 표시
# Out:
# <AxesSubplot:>

# %%
df.rolling('20D').mean().plot()
# Out:
# <AxesSubplot:>

# %%
df.c1.rolling(30, min_periods=20).mean().plot(style='--', label='Simple MA')
df.c1.ewm(span=30).mean().plot(style='-', label='EWMA')
# Out:
# <AxesSubplot:>

# %%
df.c1.rolling(100, min_periods=50).corr(df.c3).plot() #c1과 c3의 상관분석
# Out:
# <AxesSubplot:>

# %%
df.c1.rolling(100, min_periods=50).corr(df.c4).plot() #c1과 c4의 상관분석
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 데이터 읽기 및 저장

# %% [markdown]
# ### 텍스트 파일 읽기/쓰기

# %% [markdown]
# ### 이진 데이터 파일 읽기/쓰기

# %% [markdown]
# ## 데이터 정제

# %% [markdown]
# ### 누락값 처리
#
# * 대부분의 실제 데이터들은 정제되지 않고 누락값들이 존재
# * 서로 다른 데이터들은 다른 형태의 결측을 가짐
# * 결측 데이터는 `null`, `NaN`, `NA`로 표기

# %% [markdown]
# #### None: 파이썬 누락 데이터

# %% [markdown]
# #### NaN: 누락된 수치 데이터

# %% [markdown]
# #### Null 값 처리

# %% [markdown]
# ### 중복 제거

# %% [markdown]
# ### 값 치환

# %% [markdown]
# ## 참고문헌
#
# * Pandas 사이트: https://pandas.pydata.org/
# * Jake VanderPlas, "Python Data Science Handbook", O'Reilly
# * Wes Mckinney, "Python for Data Analysis", O'Reilly
